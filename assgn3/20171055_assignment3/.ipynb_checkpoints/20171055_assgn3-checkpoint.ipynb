# %%
import nltk
from collections import defaultdict

# %%
# Preprocessing raw data
def preprocessTrainingData():
    tags = []
    shabd =[]
    file = open("./anntags", "r")
    raw_data = file.read()
    sentences = raw_data.split("<s>")
    for sentence in sentences:
        tags.append("start2")
        tags.append("start1")
        shabd.append("start2")
        shabd.append("start1")
        words_info = sentence.split("\n")
        for word_info in words_info:
            tokens = word_info.split("\t")
            try:
#                 print(tokens[1], tokens[7])
                tags.append(tokens[1])
                shabd.append(tokens[0])
            except:
                print("new line")
    
    return tags, shabd

# %%
def generateCountTable(tags):
    
    tokens = nltk.word_tokenize(tags)
    bgs = nltk.ngrams(tokens,2)
    tgs = nltk.ngrams(tokens,3)
    dict_bgs = dict(nltk.FreqDist(bgs))
    dict_tgs = dict(nltk.FreqDist(tgs))
    dict_bgs = sorted(dict_bgs.items(), key = lambda kv:(kv[1], kv[0]), reverse=True)
    dict_tgs = sorted(dict_tgs.items(), key = lambda kv:(kv[1], kv[0]), reverse=True)
    
    return dict_bgs, dict_tgs

# %%
def find_tags():
    
    tags, words = preprocessTrainingData()
    return tags, words

# %%
ann_tags, ann_words = find_tags()
bi_pt, tri_pt = generateCountTable(' '.join(ann_tags))

# print(ann_tags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d405232bfdfe> in <module>
# ----> 1 ann_tags, ann_words = find_tags()
#       2 bi_pt, tri_pt = generateCountTable(' '.join(ann_tags))
#       3
#       4 # print(ann_tags)
#
# NameError: name 'find_tags' is not defined

# %%
# bi = dict(bi_pt)
# tri = dict(tri_pt)

# %%
# print(tri_pt[1][1])
bi = defaultdict(lambda : defaultdict(int))
tri = defaultdict(lambda : defaultdict(lambda: defaultdict(int)))

for i in range(len(bi_pt)):
    bi[bi_pt[i][0][0]][bi_pt[i][0][1]] = bi_pt[i][1]
    
for i in range(len(tri_pt)):
    tri[tri_pt[i][0][0]][tri_pt[i][0][1]][tri_pt[i][0][2]] = tri_pt[i][1]

# %%
# print(bi_pt)

# %%
# print(tri['lwg__psp'])
# print(ann_tags)

# %%
def ud_train_tags():
    udfile = open('./asgn3_Ud.txt', 'r')
    udinp = udfile.read()
    ud_train_tags = []
    shabd =[]
    sentences = udinp.split("<s>")
    for sentence in sentences:
        ud_train_tags.append("start2")
        ud_train_tags.append("start1")
        shabd.append("start2")
        shabd.append("start1")
        words = sentence.split("\n")
        for word in words:
            tokens = word.split("\t")
            try: 
                if len(tokens[1]) > 1:
    #                 print("this" ,tokens[1])
                    ud_train_tags.append(tokens[1])
                    shabd.append(tokens[0])
            except:
                print("new line")
    
    return ud_train_tags, shabd

# %%
ud_tags, ud_words = ud_train_tags()
# Out:
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data

# %%
# # print(ud_tags)
# for i in range(len(ud_tags)):
#     print(ann_words[i])

# %%
# for i in range(len(ud_tags)):
#     print(ud_words[i])

# %%
def find_map_with_data(ud_tags, ann_tags):
    new_map = {}
#     print(len(ud_tags), len(ann_tags))
    for i,ud in enumerate(ud_tags):
        new_map.setdefault(ud,[])
        if(ann_tags[i] not in new_map[ud]):
            new_map[ud].append(ann_tags[i])
    return new_map

# %%
new_map = find_map_with_data(ud_tags, ann_tags)
print(new_map)
# Out:
# {'start2': ['start2'], 'start1': ['start1'], 'obj': ['k2', 'ccof', 'sent-adv', 'pof', 'pof__cn', 'k1s', 'k1', 'rt'], 'nsubj': ['k1', 'k1s', 'mod', 'nmod', 'pof__cn', 'k2', 'nmod__adj', 'rsym', 'nmod__k1inv', 'k4a', 'pof', 'k7', 'ccof'], 'dep': ['lwg__rp', 'lwg__neg', 'main', 'lwg__psp', 'rs', 'mod'], 'advmod': ['lwg__neg', 'jjmod__intf', 'adv', 'k1', 'jjmod', 'k1s', 'k2', 'k7t', 'ccof', 'pof__cn'], 'root': ['main', 'r6', 'k1s', 'k2', 'rt', 'vmod', 'ccof', 'k1', 'lwg__psp', 'k7', 'nmod__k2inv', 'pof__cn', 'nmod__adj', 'rs', 'nmod', 'nmod__relc'], 'aux': ['lwg__vaux', 'main'], 'aux:pass': ['lwg__vaux_cont', 'lwg__vaux'], 'nmod': ['k5', 'r6', 'k7p', 'rsym', 'vmod', 'lwg__psp', 'r6-k2', 'k7t', 'ccof', 'nmod', 'k7', 'ras-k1', 'nmod__emph', 'nmod__adj', 'k1', 'lwg__neg', 'rh', 'k1s', 'pof__cn', 'jjmod', 'k1u', 'k3', 'adv', 'fragof', 'rsp', 'lwg__rp', 'rt'], 'case': ['lwg__psp', 'lwg__rp', 'mod', 'vmod', 'pof__cn', 'nmod__adj'], 'compound': ['nmod', 'pof__cn', 'pof', 'k2', 'k1', 'vmod', 'r6', 'rsym', 'nmod__adj', 'k7t', 'ccof', 'nmod__k1inv', 'lwg__rp'], 'punct': ['lwg__psp', 'rsym', 'pof__cn', 'rysm'], 'amod': ['nmod__adj', 'adv', 'mod', 'nmod', 'rsym', 'ccof', 'k1', 'jjmod__intf', 'pof__cn'], 'cop': ['main', 'nmod', 'nmod__k1inv', 'ccof', 'vmod', 'mod', 'rs', 'k2', 'rsym', 'nmod__relc'], 'nummod': ['nmod__adj', 'rsym'], 'obl': ['k7t', 'k2p', 'k7', 'rt', 'k5', 'rh', 'vmod', 'sent-adv', 'adv', 'k7p', 'k7a', 'k1', 'ras-k1', 'ccof', 'k3', 'rsym', 'rd', 'k2', 'lwg__psp', 'r6', 'main', 'nmod', 'k1s'], 'det': ['nmod__adj', 'rt'], 'acl': ['k2s', 'nmod__k1inv', 'pof', 'vmod', 'rsym', 'ccof', 'lwg__vaux', 'adv', 'nmod__k2inv'], 'cc': ['k2', 'k1', 'main', 'r6', 'k7', 'k7t', 'k7p', 'nmod', 'rs', 'ccof', 'rh', 'fragof', 'pof', 'k1s', 'lwg__psp'], 'conj': ['ccof', 'r6', 'pof__cn', 'k7p', 'k7', 'main', 'k1s', 'nmod__k1inv', 'k1', 'vmod'], 'xcomp': ['k1s', 'k2', 'k1', 'nmod__adj', 'pof'], 'mark': ['lwg__psp', 'rs', 'k2', 'nmod__relc', 'rsym', 'main', 'k1', 'lwg__vaux', 'vmod'], 'advcl': ['rh', 'rt', 'vmod', 'ccof', 'nmod__relc', 'main'], 'nsubj:pass': ['k1', 'k4', 'k2s'], 'iobj': ['k4', 'k2'], 'acl:relcl': ['nmod__relc', 'main', 'k1s', 'nmod__k1inv', 'k1'], 'dislocated': ['lwg__psp']}

# %%
ud_tagset = ['acl', 'neg', 'dislocated', 'nmod', 'iobj', 'punct', 'vocative', 'advmod', 'dep', 'compound', 'case'
            , 'det', 'dobj', 'amod', 'parataxis', 'ccomp','xcomp', 'aux', 'auxpass', 'nsubj','nsubjpass',
             'nummod','advcl','root','conj','csubj','obj','obl','expl','discourse','cop','mark','appos',
             'clf','fixed','flat','list_','orphan','goeswith','reparandum','cc']

# %%
mapping = {'acl' : ['nmod_k1inv', 'nmod_k2inv', 'nmod_relc', 'rs', 'k2g', 'k2s', 'rbmod_relc'], 
           'neg' : ['nmod_neg', 'lwg_neg'], 'dislocated' : ['fragof'], 
           'nmod' : ['k2u', 'jk1', 'k1u', 'k3', 'k3u', 'k2p', 'k4u', 'k5', 'k7', 'k7a', 'k7p', 'k7pu', 'k7t', 'k7tu',
                       'k7u','r6', 'r6-k1', 'r6-k2', 'r6v', 'ras-k1', 'ras-k1u', 'ras-k2', 'ras-k4', 'ras-k4a', 
                       'ras-k7', 'ras-k7p','ras-neg', 'ras-pof', 'ras-r6', 'ras-r6-k2', 'ras-rt','nmod_emph'], 
           'iobj' : ['k4'], 
           'punct' : ['rsym'], 
           'start1' : ['start1'],
           'start2' : ['start2'],
           'vocative' : ['rad'], 
           'nmod:poss' : ['r6'],
           'advmod' : ['rd', 'rsp', 'lwg_intf', 'vmod_adv', 'jjmod_intf', 'jjmod', 'adv', 'rbmod'], 
           'dep' : ['lwg_rp', 'lwg_unk', 'undef'], 
           'compound' : ['pof_cn', 'pof_redup', 'lwg_rdp', 'lwg_vm', 'nmod_pofinv', 'pof', 'pof_inv'], 
           'case' : ['lwg_psp', 'lwg_nst', 'psp_cl', 'lwg_k1'], 
           'det' : ['mod_wq'], 
           'dobj' : ['k2', 'k1s', 'mk1'], 
           'amod' : ['nmod_adj', 'nmod'], 
           'parataxis' : ['vmod'], 'ccomp' : ['k2'], 
           'xcomp' : ['k2'], 
           'aux' : ['lwg_vaux', 'lwg_vaux_cont'], 
           'aux:pass' : ['lwg_vaux'], 
           'nsubj' : ['k1', 'k4a', 'pk1', 'k1s', 'mod', 'nmod', 'k2'], 
           'nsubj:pass' : ['k1'], 
           'nummod' : ['enm'], 
           'advcl' : ['rh', 'rt', 'rtu', 'sent-adv', 'vmod'], 
           'root' : ['root'], 
           'conj' : ['ccof'], 
           'csubj' : [''], 
           'obj' : ['k2', 'ccof', 'sent-adv', 'pof', 'pof__cn', 'k1s', 'k1', 'rt'], 
           'obl' : ['k7t', 'k2p', 'k7', 'rt', 'k5', 'rh', 'vmod', 'sent-adv', 'adv', 'k7p', 'k7a', 'k1', 'ras-k1', 'ccof', 'k3', 'rsym', 'rd', 'k2', 'nmod', 'k1s'], 
           'expl' : [''], 
#            'discourse' : [''], 'cop' : [''], 'mark' : [''], 'appos' : [''], 'clf' : [''], 'fixed' : [''], 
#            'flat' : [''], 'list_' : [''], 'orphan' : [''], 'goeswith' : [''], 'reparandum' : [''], 
           'cc' : ['k1']}

# %%
def generateUDCountTable(tags):
    tokens = nltk.word_tokenize(tags)
    bgs = nltk.ngrams(tokens,2)
    dict_bgs = dict(nltk.FreqDist(bgs))
    dict_bgs = sorted(dict_bgs.items(), key = lambda kv:(kv[1], kv[0]), reverse=True)
    
    return dict_bgs

# %%
bi_ud_old = generateUDCountTable(' '.join(ud_tags))

# %%
bi_ud = defaultdict(lambda : defaultdict(int))

for i in range(len(bi_ud_old)):
    bi_ud[bi_ud_old[i][0][0]][bi_ud_old[i][0][1]] = bi_ud_old[i][1]

# %%
def preprocessUDInput():
    tags =[]
    shabd =[]
    inputfile = open("./20171099/Udfile.txt", "r")
    inputtext = inputfile.read()
    sentences = inputtext.split("<s>")
    for sentence in sentences:
        tags.append("start2")
        tags.append("start1")
        shabd.append("start2")
        shabd.append("start1")
        words = sentence.split("\n")
        for word in words:
            tokens = word.split("\t")
#             print(tokens)
            try:
    #                 print(tokens[1], tokens[7])
                shabd.append(tokens[0])
                tags.append(tokens[1])
            except:
                print("WARNING: No problem, just an empty line detected in raw data")
                
    return tags, shabd

# %%
def preprocessAnnCorraInput():
    tags =[]
    shabd =[]
    inputfile = open("./20171099/annCorrafile.txt", "r")
    inputtext = inputfile.read()
    sentences = inputtext.split("<s>")
    for sentence in sentences:
        tags.append("start2")
        tags.append("start1")
        shabd.append("start2")
        shabd.append("start1")
        words_info = sentence.split("\n")
        for word_info in words_info:
            tokens = word_info.split("\t")
            try:
    #                 print(tokens[1], tokens[7])
                shabd.append(tokens[1])
                tags.append(tokens[7])
            except:
                print("WARNING: No problem, just an empty line detected in raw data")
                
    return tags, shabd

# %%
# inp_tags = ['start2', 'start1','amod', 'nsubj', 'cc', 'amod', 'conj', 'nmod:poss', 'dobj', 'case', 'root', 'aux', 'punct']
# inp_tags = ['start2', 'start1','r6', 'ccof', 'k7p', 'ccof', 'lwg_psp', 'lwg_psp', 'k1', 'pof', 'root', 'lwg_vaux', 'rsym']

# %%
def findTagsetUsed(inp_tags):
    #MANUALLY CHANGE
    findUDtoAnnTag = True
    if findUDtoAnnTag == True:
        inp_tags, words = preprocessUDInput()

    if findUDtoAnnTag == False:
        inp_tags, words = preprocessAnnCorraInput()
        
    
    return findUDtoAnnTag, inp_tags, words

# %%
findUDtoAnnTag, inp_tags, words = findTagsetUsed(inp_tags)
# Out:
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data
# WARNING: No problem, just an empty line detected in raw data

# %%
print(inp_tags)
# Out:
# ['start2', 'start1', 'obl', 'case', 'compound', 'nmod', 'nsubj', 'case', 'amod', 'obl', 'case', 'case', 'compound', 'obj', 'case', 'advcl', 'amod', 'amod', 'nmod', 'compound', 'obj', 'case', 'compound', 'nmod', 'case', 'acl', 'root', 'aux', 'punct', 'start2', 'start1', 'obl', 'case', 'obj', 'compound', 'advcl', 'mark', 'mark', 'amod', 'nmod', 'compound', 'compound', 'obj', 'case', 'compound', 'compound', 'nmod', 'case', 'acl', 'root', 'aux', 'punct', 'cc', 'nmod', 'nmod', 'case', 'nsubj', 'nmod', 'case', 'nsubj', 'amod', 'advmod', 'case', 'compound', 'conj', 'punct', 'start2', 'start1', 'compound', 'nmod', 'case', 'nsubj', 'nmod', 'mark', 'nummod', 'obl', 'case', 'case', 'dep', 'nummod', 'amod', 'nsubj:pass', 'obj', 'case', 'advcl', 'root', 'aux:pass', 'punct', 'start2', 'start1', 'iobj', 'case', 'obj', 'amod', 'mark', 'nmod', 'case', 'amod', 'nmod', 'punct', 'amod', 'conj', 'cc', 'amod', 'conj', 'case', 'case', 'nsubj', 'cc', 'amod', 'conj', 'root', 'cop', 'punct', 'start2', 'start1', 'nmod', 'case', 'obl', 'case', 'det', 'nsubj', 'case', 'obl', 'case', 'obl', 'dep', 'obj', 'case', 'advmod', 'root', 'punct', 'start2', 'start1', 'nummod', 'amod', 'nmod', 'case', 'obj', 'advcl', 'mark', 'nsubj', 'case', 'advmod', 'amod', 'compound', 'root', 'aux', 'punct', 'start2', 'start1', 'compound', 'obl', 'cc', 'conj', 'case', 'nmod', 'nsubj', 'case', 'obj', 'case', 'nmod', 'case', 'obj', 'nmod', 'cc', 'advmod', 'conj', 'mark', 'obj', 'root', 'aux', 'cc', 'nummod', 'dep', 'nsubj', 'obj', 'obl', 'mark', 'amod', 'advmod', 'case', 'compound', 'conj', 'punct', 'start2', 'start1', 'nmod', 'obl', 'case', 'nsubj', 'compound', 'advcl', 'mark', 'mark', 'compound', 'advcl', 'root', 'aux', 'punct', 'start2', 'start1', 'det', 'nmod', 'case', 'obj', 'advcl', 'mark', 'mark', 'obl', 'case', 'case', 'nmod', 'case', 'compound', 'obj', 'compound', 'nsubj', 'amod', 'compound', 'root', 'aux', 'aux:pass', 'punct', 'start2', 'start1', 'det', 'nmod', 'case', 'compound', 'nmod', 'case', 'amod', 'nmod', 'compound', 'nmod', 'punct', 'compound', 'nmod', 'case', 'nmod', 'compound', 'conj', 'punct', 'amod', 'nmod', 'compound', 'conj', 'punct', 'amod', 'nmod', 'compound', 'conj', 'cc', 'amod', 'nmod', 'cc', 'amod', 'nmod', 'compound', 'compound', 'conj', 'case', 'det', 'nsubj', 'root', 'cop', 'punct', 'start2', 'start1', 'nmod', 'case', 'obl', 'case', 'nmod', 'case', 'obl', 'case', 'case', 'nsubj', 'case', 'obl', 'case', 'nmod', 'cc', 'conj', 'obl', 'case', 'obl', 'case', 'case', 'nummod', 'amod', 'obj', 'case', 'nmod', 'mark', 'compound', 'root', 'aux', 'punct', 'start2', 'start1', 'nmod', 'case', 'obl', 'case', 'nsubj', 'obl', 'case', 'obl', 'cc', 'nmod', 'conj', 'case', 'obl', 'case', 'case', 'amod', 'amod', 'nmod', 'case', 'compound', 'root', 'punct', 'start2', 'start1', 'det', 'nmod', 'case', 'obl', 'case', 'det', 'nsubj', 'case', 'compound', 'root', 'nsubj', 'obl', 'case', 'obl', 'punct', 'conj', 'cc', 'conj', 'case', 'nmod', 'obj', 'case', 'obj', 'acl:relcl', 'aux', 'punct', 'start2', 'start1', 'compound', 'nmod', 'case', 'compound', 'compound', 'nmod', 'compound', 'obl', 'case', 'case', 'compound', 'nmod', 'case', 'compound', 'obl', 'case', 'nsubj', 'obl', 'case', 'obl', 'case', 'case', 'amod', 'nsubj', 'nmod', 'case', 'compound', 'root', 'punct', 'start2', 'start1', 'det', 'nsubj', 'compound', 'nmod', 'punct', 'compound', 'nummod', 'compound', 'compound', 'nsubj', 'det', 'obl', 'case', 'obl', 'case', 'nmod', 'nmod', 'nummod', 'obl', 'advcl', 'amod', 'obl', 'nmod', 'nmod', 'nummod', 'obl', 'obl', 'root', 'punct', 'start2', 'start1', 'obl', 'case', 'nsubj', 'obl', 'case', 'nmod', 'case', 'nmod', 'obl', 'case', 'compound', 'advcl', 'amod', 'obl', 'nmod', 'nmod', 'nummod', 'obl', 'obl', 'root', 'punct', 'start2', 'start1', 'det', 'obl', 'det', 'iobj', 'case', 'nmod', 'punct', 'conj', 'punct', 'conj', 'punct', 'conj', 'punct', 'conj', 'punct', 'compound', 'conj', 'punct', 'compound', 'conj', 'punct', 'compound', 'conj', 'punct', 'conj', 'cc', 'conj', 'obl', 'case' ...

# %%
if findUDtoAnnTag == False:
    ud = []
    dictionary_of_possibilities = {}
    for tag in inp_tags:
        for i,ann_tag in enumerate(list(mapping.values())):
            if tag in ann_tag:
#                 print(tag, list(mapping.keys())[i])
                dictionary_of_possibilities.setdefault(tag,[])
                if(list(mapping.keys())[i] not in dictionary_of_possibilities[tag]):
                    dictionary_of_possibilities[tag].append(list(mapping.keys())[i])

    for i in range(len(inp_tags)):
        try:
            if len(dictionary_of_possibilities[inp_tags[i]]) == 1:
                ud.append(dictionary_of_possibilities[inp_tags[i]][0])
            elif len(dictionary_of_possibilities[inp_tags[i]]) > 1:
                max_score = 0
                for possibility in dictionary_of_possibilities[inp_tags[i]]:
                    score = bi_ud[ud[-1]][possibility]
                    if score != 0: #bigram found
                        if score > max_score:
                            max_score = score
                            ud_tag = possibility

                    else:
                        if len(list(bi[ud[-1]])) != 0:
                            ud_tag = (list(bi[ud[-1]])[0])
                        else:
                            ud_tag = ("case") #most_frequent_tag 

                    ud.append(ud_tag)
                    break;  
        except:
            if len(list(bi[ud[-1]])) != 0:
                ud_tag = (list(bi[ud[-1]])[0])
            else:
                ud_tag = ("case") #most_frequent_tag 

            ud.append(ud_tag)

    print("S.No.\t\tWord\t\tAnnCorra\t\tUD\n")
    for i, ann in enumerate(inp_tags):
        print(i, "\t\t", words[i], "\t\t",ann, "\t\t", ud[i])

# %%
# print(list(mapping.values())[0])

# %%
# print(findUDtoAnnTag)
if findUDtoAnnTag == True:
    ann = []
    for i in range(len(inp_tags)):
        try:
            if len(mapping[inp_tags[i]]) == 1:
                ann.append(mapping[inp_tags[i]][0])

            elif len(mapping[inp_tags[i]]) > 1:
                max_score = 0

                #check bigrams
                for mapped in mapping[inp_tags[i]]:    
                    score = bi[ann[-1]][mapped]
                    if score != 0: #bigram found
                        if score > max_score:
                            max_score = score
                            ann_tag = mapped

                    else:
                        if len(list(tri[ann[-2]][ann[-1]])) != 0:
                            ann_tag = (list(tri[ann[-2]][ann[-1]])[0])
                        elif len(list(bi[ann[-1]])) != 0:
                            ann_tag = (list(bi[ann[-1]])[0])
                        else:
                            ann_tag = ("lwg_psp") #most_frequent_tag 

                    ann.append(ann_tag)
                    break;  
        except:
            if len(list(tri[ann[-2]][ann[-1]])) != 0:
                ann_tag = (list(tri[ann[-2]][ann[-1]])[0])
            elif len(list(bi[ann[-1]])) != 0:
                ann_tag = (list(bi[ann[-1]])[0])
            else:
                ann_tag = ("lwg_psp") #most_frequent_tag 

            ann.append(ann_tag)
    
    print("S.No.\t\tUD\t\tAnnCorra\n")
    for i, ud in enumerate(inp_tags):
        print(i, "\t\t", ud, "\t\t", ann[i])
# Out:
# S.No.		UD		AnnCorra
#
# 0 		 start2 		 start2
# 1 		 start1 		 start1
# 2 		 obl 		 k7t
# 3 		 case 		 lwg__psp
# 4 		 compound 		 lwg__psp
# 5 		 nmod 		 pof
# 6 		 nsubj 		 k1
# 7 		 case 		 pof
# 8 		 amod 		 ccof
# 9 		 obl 		 k7t
# 10 		 case 		 ccof
# 11 		 case 		 lwg__psp
# 12 		 compound 		 nmod__adj
# 13 		 obj 		 k2
# 14 		 case 		 lwg__psp
# 15 		 advcl 		 rh
# 16 		 amod 		 lwg__psp
# 17 		 amod 		 lwg__psp
# 18 		 nmod 		 pof
# 19 		 compound 		 main
# 20 		 obj 		 k2
# 21 		 case 		 lwg__psp
# 22 		 compound 		 pof
# 23 		 nmod 		 main
# 24 		 case 		 lwg__vaux
# 25 		 acl 		 start2
# 26 		 root 		 root
# 27 		 aux 		 lwg_vaux
# 28 		 punct 		 rsym
# 29 		 start2 		 start2
# 30 		 start1 		 start1
# 31 		 obl 		 k7t
# 32 		 case 		 lwg__psp
# 33 		 obj 		 k2
# 34 		 compound 		 lwg__psp
# 35 		 advcl 		 rh
# 36 		 mark 		 lwg__psp
# 37 		 mark 		 lwg__psp
# 38 		 amod 		 pof
# 39 		 nmod 		 main
# 40 		 compound 		 lwg__vaux
# 41 		 compound 		 start2
# 42 		 obj 		 start1
# 43 		 case 		 nmod__adj
# 44 		 compound 		 k1
# 45 		 compound 		 lwg__psp
# 46 		 nmod 		 r6
# 47 		 case 		 lwg__psp
# 48 		 acl 		 nmod__adj
# 49 		 root 		 root
# 50 		 aux 		 lwg_vaux
# 51 		 punct 		 rsym
# 52 		 cc 		 k1
# 53 		 nmod 		 nmod__adj
# 54 		 nmod 		 k1s
# 55 		 case 		 main
# 56 		 nsubj 		 k1
# 57 		 nmod 		 lwg__psp
# 58 		 case 		 r6
# 59 		 nsubj 		 k1
# 60 		 amod 		 lwg__rp
# 61 		 advmod 		 nmod__adj
# 62 		 case 		 k1s
# 63 		 compound 		 main
# 64 		 conj 		 ccof
# 65 		 punct 		 rsym
# 66 		 start2 		 start2
# 67 		 start1 		 start1
# 68 		 compound 		 nmod__adj
# 69 		 nmod 		 k1
# 70 		 case 		 lwg__psp
# 71 		 nsubj 		 k1
# 72 		 nmod 		 lwg__psp
# 73 		 mark 		 lwg__psp
# 74 		 nummod 		 enm
# 75 		 obl 		 k7t
# 76 		 case 		 lwg__psp
# 77 		 case 		 lwg__psp
# 78 		 dep 		 pof
# 79 		 nummod 		 enm
# 80 		 amod 		 k7t
# 81 		 nsubj:pass 		 k1
# 82 		 obj 		 k2
# 83 		 case 		 nmod__relc
# 84 		 advcl 		 start2
# 85 		 root 		 root
# 86 		 aux:pass 		 lwg_vaux
# 87 		 punct 		 rsym
# 88 		 start2 		 start2
# 89 		 start1 		 start1
# 90 		 iobj 		 k4
# 91 		 case 		 lwg__psp
# 92 		 obj 		 k2
# 93 		 amod 		 lwg__psp
# 94 		 mark 		 lwg__psp
# 95 		 nmod 		 pof
# 96 		 case 		 main
# 97 		 amod 		 lwg__vaux
# 98 		 nmod 		 start2
# 99 		 punct 		 rsym
# 100 		 amod 		 rsym
# 101 		 conj 		 ccof
# 102 		 cc 		 k1
# 103 		 amod 		 r6
# 104 		 conj 		 ccof
# 105 		 case 		 lwg__psp
# 106 		 case 		 nmod__adj
# 107 		 nsubj 		 k1
# 108 		 cc 		 k1
# 109 		 amod 		 r6
# 110 		 conj 		 ccof
# 111 		 root 		 root
# 112 		 cop 		 lwg_vaux
# 113 		 punct 		 rsym
# 114 		 start2 		 start2
# 115 		 start1 		 start1
# 116 		 nmod 		 nmod__adj
# 117 		 case 		 k1
# 118 		 obl 		 k7t
# 119 		 case 		 lwg__psp
# 120 		 det 		 mod_wq
# 121 		 nsubj 		 k1
# 122 		 case 		 lwg__psp
# 123 		 obl 		 k7t
# 124 		 case 		 lwg__psp
# 125 		 obl 		 k7t
# 126 		 dep 		 lwg__psp
# 127 		 obj 		 k2
# 128 		 case 		 lwg__psp
# 129 		 advmod 		 rd
# 130 		 root 		 root
# 131 		 punct 		 rsym
# 132 		 start2 		 start2
# 133 		 start1 		 start1
# 134 		 nummod 		 enm
# 135 		 amod 		 k7t
# 136 		 nmod 		 lwg__psp
# 137 		 case 		 lwg__psp
# 138 		 obj 		 k2
# 139 		 advcl 		 lwg__psp
# 140 		 mark 		 lwg__psp
# 141 		 nsubj 		 k1
# 142 		 case 		 lwg__psp
# 143 		 advmod 		 rd
# 144 		 amod 		 lwg__psp
# 145 		 compound 		 lwg__psp
# 146 		 root 		 root
# 147 		 aux 		 lwg_vaux
# 148 		 punct 		 rsym
# 149 		 start2 		 start2
# 150 		 start1 		 start1
# 151 		 compound 		 nmod__adj
# 152 		 obl 		 k7t
# 153 		 cc 		 k1
# 154 		 conj 		 ccof
# 155 		 case 		 main
# 156 		 nmod 		 start2
# 157 		 nsubj 		 start1
# 158 		 case 		 nmod__adj
# 159 		 obj 		 k2
# 160 		 case 		 lwg__psp
# 161 		 nmod 		 pof
# 162 		 case 		 main
# 163 		 obj 		 k2
# 164 		 nmod 		 lwg__psp
# 165 		 cc 		 k1
# 166 		 advmod 		 lwg__psp
# 167 		 conj 		 ccof
# 168 		 mark 		 lwg__psp
# 169 		 obj 		 k2
# 170 		 root 		 root
# 171 		 aux 		 lwg_vaux
# 172 		 cc 		 k1
# 173 		 nummod 		 enm
# 174 		 dep 		 k7t
# 175 		 nsubj 		 k1
# 176 		 obj 		 k2
# 177 		 obl 		 k7t
# 178 		 mark 		 lwg__psp
# 179 		 amod 		 lwg__psp
# 180 		 advmod 		 rd
# 181 		 case 		 lwg__psp
# 182 		 compound 		 lwg__psp
# 183 		 conj 		 ccof
# 184 		 punct 		 rsym
# 185 		 start2 		 start2
# 186 		 start1 		 start1
# 187 		 nmod 		 nmod__adj
# 188 		 obl 		 k7t
# 189 		 case 		 lwg__psp
# 190 		 nsubj 		 k1
# 191 		 compound 		 lwg__psp
# 192 		 advcl 		 rh
# 193 		 mark 		 lwg__psp
# 194 		 mark 		 lwg__psp
# 195 		 compound 		 pof
# 196 		 advcl 		 rh
# 197 		 root 		 root
# 198 		 aux 		 lwg_vaux
# 199 		 punct 		 rsym
# 200 		 start2 		 start2
# 201 		 start1 		 start1
# 202 		 det 		 mod_wq
# 203 		 nmod 		 k1
# 204 		 case 		 lwg__psp
# 205 		 obj 		 k2
# 206 		 advcl 		 lwg__psp
# 207 		 mark 		 lwg__psp
# 208 		 mark 		 lwg__psp
# 209 		 obl 		 k7t
# 210 		 case 		 lwg__psp
# 211 		 case 		 lwg__psp
# 212 		 nmod 		 pof
# 213 		 case 		 main
# 214 		 compound 		 lwg__vaux
# 215 		 obj 		 k2
# 216 		 compound 		 nmod__adj
# 217 		 nsubj 		 k1
# 218 		 amod 		 lwg__psp
# 219 		 compound 		 r6
# 220 		 root 		 root
# 221 		 aux 		 lwg_vaux
# 222 		 aux:pass 		 lwg_vaux
# 223 		 punct 		 rsym
# 224 		 start2 		 start2
# 225 		 start1 		 start1
# 226 		 det 		 mod_wq
# 227 		 nmod 		 k1
# 228 		 case 		 lwg__psp
# 229 		 compound 		 r6
# 230 		 nmod 		 lwg__psp
# 231 		 case 		 nmod__adj
# 232 		 amod 		 nmod__adj
# 233 		 nmod 		 pof__cn
# 234 		 compound 		 k1
# 235 		 nmod 		 lwg__psp
# 236 		 punct 		 rsym
# 237 		 compound 		 rsym
# 238 		 nmod 		 rsym
# 239 		 case 		 rsym
# 240 		 nmod 		 rsym
# 241 		 compound 		 rsym
# 242 		 conj 		 ccof
# 243 		 punct 		 rsym
# 244 		 amod 		 start2
# 245 		 nmod 		 start1
# 246 		 compound 		 nmod__adj
# 247 		 conj 		 ccof
# 248 		 punct 		 rsym
# 249 		 amod 		 start2
# 250 		 nmod 		 start1
# 251 		 compound 		 nmod__adj
# 252 		 conj 		 ccof
# 253 		 cc 		 k1
# 254 		 amod 		 r6
# 255 		 nmod 		 lwg__psp
# 256 		 cc 		 k1
# 257 		 amod 		 lwg__psp
# 258 		 nmod 		 r6
# 259 		 compound 		 lwg__psp
# 260 		 compound 		 nmod__adj
# 261 		 conj 		 ccof
# 262 		 case 		 k2
# 263 		 det 		 mod_wq
# 264 		 nsubj 		 k1
# 265 		 root 		 root
# 266 		 cop 		 lwg_vaux
# 267 		 punct 		 rsym
# 268 		 start2 		 start2
# 269 		 start1 		 start1
# 270 		 nmod 		 nmod__adj
# 271 		 case 		 k1
# 272 		 obl 		 k7t
# 273 		 case 		 lwg__psp
# 274 		 nmod 		 lwg__psp
# 275 		 case 		 pof
# 276 		 obl 		 k7t
# 277 		 case 		 lwg__psp
# 278 		 case 		 lwg__psp
# 279 		 nsubj 		 k1
# 280 		 case 		 lwg__psp
# 281 		 obl 		 k7t
# 282 		 case 		 lwg__psp
# 283 		 nmod 		 lwg__psp
# 284 		 cc 		 k1
# 285 		 conj 		 ccof
# 286 		 obl 		 k7t
# 287 		 case 		 ccof
# 288 		 obl 		 k7t
# 289 		 case 		 ccof
# 290 		 case 		 lwg__psp
# 291 		 nummod 		 enm
# 292 		 amod 		 k7t
# 293 		 obj 		 k2
# 294 		 case 		 nmod__relc
# 295 		 nmod 		 start2
# 296 		 mark 		 lwg__psp
# 297 		 compound 		 nmod__adj
# 298 		 root 		 root
# 299 		 aux 		 lwg_vaux
# 300 		 punct 		 rsym
# 301 		 start2 		 start2
# 302 		 start1 		 start1
# 303 		 nmod 		 nmod__adj
# 304 		 case 		 k1
# 305 		 obl 		 k7t
# 306 		 case 		 lwg__psp
# 307 		 nsubj 		 k1
# 308 		 obl 		 k7t
# 309 		 case 		 lwg__psp
# 310 		 obl 		 k7t
# 311 		 cc 		 k1
# 312 		 nmod 		 r6
# 313 		 conj 		 ccof
# 314 		 case 		 lwg__psp
# 315 		 obl 		 k7t
# 316 		 case 		 lwg__psp
# 317 		 case 		 lwg__psp
# 318 		 amod 		 pof
# 319 		 amod 		 main
# 320 		 nmod 		 lwg__vaux
# 321 		 case 		 start2
# 322 		 compound 		 start1
# 323 		 root 		 root
# 324 		 punct 		 rsym
# 325 		 start2 		 start2
# 326 		 start1 		 start1
# 327 		 det 		 mod_wq
# 328 		 nmod 		 k1
# 329 		 case 		 lwg__psp
# 330 		 obl 		 k7t
# 331 		 case 		 lwg__psp
# 332 		 det 		 mod_wq
# 333 		 nsubj 		 k1
# 334 		 case 		 lwg__psp
# 335 		 compound 		 r6
# 336 		 root 		 root
# 337 		 nsubj 		 lwg_vaux
# 338 		 obl 		 k7t
# 339 		 case 		 lwg__psp
# 340 		 obl 		 k7t
# 341 		 punct 		 rsym
# 342 		 conj 		 ccof
# 343 		 cc 		 k1
# 344 		 conj 		 ccof
# 345 		 case 		 main
# 346 		 nmod 		 start2
# 347 		 obj 		 start1
# 348 		 case 		 nmod__adj
# 349 		 obj 		 k2
# 350 		 acl:relcl 		 lwg__psp
# 351 		 aux 		 pof
# 352 		 punct 		 rsym
# 353 		 start2 		 start2
# 354 		 start1 		 start1
# 355 		 compound 		 nmod__adj
# 356 		 nmod 		 k1
# 357 		 case 		 lwg__psp
# 358 		 compound 		 r6
# 359 		 compound 		 lwg__psp
# 360 		 nmod 		 nmod__adj
# 361 		 compound 		 nmod__adj
# 362 		 obl 		 k7t
# 363 		 case 		 lwg__psp
# 364 		 case 		 lwg__psp
# 365 		 compound 		 pof
# 366 		 nmod 		 main
# 367 		 case 		 lwg__vaux
# 368 		 compound 		 start2
# 369 		 obl 		 start1
# 370 		 case 		 nmod__adj
# 371 		 nsubj 		 k1
# 372 		 obl 		 k7t
# 373 		 case 		 lwg__psp
# 374 		 obl 		 k7t
# 375 		 case 		 lwg__psp
# 376 		 case 		 lwg__psp
# 377 		 amod 		 pof
# 378 		 nsubj 		 k1
# 379 		 nmod 		 pof
# 380 		 case 		 ccof
# 381 		 compound 		 lwg__vaux
# 382 		 root 		 root
# 383 		 punct 		 rsym
# 384 		 start2 		 start2
# 385 		 start1 		 start1
# 386 		 det 		 mod_wq
# 387 		 nsubj 		 k1
# 388 		 compound 		 lwg__psp
# 389 		 nmod 		 r6
# 390 		 punct 		 rsym
# 391 		 compound 		 lwg__psp
# 392 		 nummod 		 enm
# 393 		 compound 		 k7t
# 394 		 compound 		 lwg__psp
# 395 		 nsubj 		 k1
# 396 		 det 		 mod_wq
# 397 		 obl 		 k1
# 398 		 case 		 lwg__psp
# 399 		 obl 		 k7t
# 400 		 case 		 lwg__psp
# 401 		 nmod 		 lwg__psp
# 402 		 nmod 		 pof
# 403 		 nummod 		 enm
# 404 		 obl 		 k7t
# 405 		 advcl 		 lwg__psp
# 406 		 amod 		 lwg__psp
# 407 		 obl 		 k7t
# 408 		 nmod 		 lwg__psp
# 409 		 nmod 		 lwg__psp
# 410 		 nummod 		 enm
# 411 		 obl 		 k7t
# 412 		 obl 		 lwg__psp
# 413 		 root 		 root
# 414 		 punct 		 rsym
# 415 		 start2 		 start2
# 416 		 start1 		 start1
# 417 		 obl 		 k7t
# 418 		 case 		 lwg__psp
# 419 		 nsubj 		 k1
# 420 		 obl 		 k7t
# 421 		 case 		 lwg__psp
# 422 		 nmod 		 lwg__psp
# 423 		 case 		 pof
# 424 		 nmod 		 main
# 425 		 obl 		 k7t
# 426 		 case 		 lwg__psp
# 427 		 compound 		 lwg__psp
# 428 		 advcl 		 rh
# 429 		 amod 		 lwg__psp
# 430 		 obl 		 k7t
# 431 		 nmod 		 lwg__psp
# 432 		 nmod 		 lwg__psp
# 433 		 nummod 		 enm
# 434 		 obl 		 k7t
# 435 		 obl 		 lwg__psp
# 436 		 root 		 root
# 437 		 punct 		 rsym
# 438 		 start2 		 start2
# 439 		 start1 		 start1
# 440 		 det 		 mod_wq
# 441 		 obl 		 k1
# 442 		 det 		 mod_wq
# 443 		 iobj 		 k4
# 444 		 case 		 lwg__psp
# 445 		 nmod 		 nmod__adj
# 446 		 punct 		 rsym
# 447 		 conj 		 ccof
# 448 		 punct 		 rsym
# 449 		 conj 		 ccof
# 450 		 punct 		 rsym
# 451 		 conj 		 ccof
# 452 		 punct 		 rsym
# 453 		 conj 		 ccof
# 454 		 punct 		 rsym
# 455 		 compound 		 start2
# 456 		 conj 		 ccof
# 457 		 punct 		 rsym
# 458 		 compound 		 start2
# 459 		 conj 		 ccof
# 460 		 punct 		 rsym
# 461 		 compound 		 start2
# 462 		 conj 		 ccof
# 463 		 punct 		 rsym
# 464 		 conj 		 ccof
# 465 		 cc 		 k1
# 466 		 conj 		 ccof
# 467 		 obl 		 k7t
# 468 		 case 		 ccof
# 469 		 compound 		 lwg__psp
# 470 		 root 		 root
# 471 		 aux:pass 		 lwg_vaux
# 472 		 punct 		 rsym
# 473 		 start2 		 start2
# 474 		 start1 		 start1
# 475 		 det 		 mod_wq
# 476 		 obl 		 k1
# 477 		 case 		 lwg__psp
# 478 		 nummod 		 enm
# 479 		 compound 		 k7t
# 480 		 compound 		 lwg__psp
# 481 		 obj 		 k2
# 482 		 punct 		 rsym
# 483 		 nummod 		 enm
# 484 		 nmod 		 k7t
# 485 		 compound 		 lwg__psp
# 486 		 conj 		 ccof
# 487 		 punct 		 rsym
# 488 		 nummod 		 enm
# 489 		 conj 		 ccof
# 490 		 cc 		 k1
# 491 		 nummod 		 enm
# 492 		 compound 		 k7t
# 493 		 conj 		 ccof
# 494 		 root 		 root
# 495 		 aux:pass 		 lwg_vaux
# 496 		 punct 		 rsym
# 497 		 start2 		 start2
# 498 		 start1 		 start1
# 499 		 compound 		 nmod__adj
# 500 		 nmod 		 k1
# 501 		 case 		 lwg__psp
# 502 		 compound 		 r6
# 503 		 nmod 		 lwg__psp
# 504 		 case 		 nmod__adj
# 505 		 root 		 root
# 506 		 cop 		 lwg_vaux
# 507 		 punct 		 rsym
# 508 		 start2 		 start2
# 509 		 start1 		 start1
# 510 		 det 		 mod_wq
# 511 		 obl 		 k1
# 512 		 case 		 lwg__psp
# 513 		 nsubj 		 k1
# 514 		 advmod 		 lwg__psp
# 515 		 nmod 		 r6
# 516 		 obl 		 k7t
# 517 		 case 		 lwg__psp
# 518 		 case 		 lwg__psp
# 519 		 advmod 		 rd
# 520 		 obj 		 lwg__psp
# 521 		 root 		 root
# 522 		 aux 		 lwg_vaux
# 523 		 punct 		 rsym
# 524 		 start2 		 start2
# 525 		 start1 		 start1
# 526 		 obl 		 k7t
# 527 		 nmod 		 lwg__psp
# 528 		 case 		 lwg__psp
# 529 		 nmod 		 pof
# 530 		 case 		 main
# 531 		 nummod 		 enm
# 532 		 obl 		 k7t
# 533 		 case 		 lwg__psp
# 534 		 nmod 		 lwg__psp
# 535 		 nmod 		 pof
# 536 		 nsubj 		 k1
# 537 		 case 		 pof
# 538 		 nummod 		 enm
# 539 		 amod 		 k7t
# 540 		 compound 		 lwg__psp
# 541 		 compound 		 lwg__psp
# 542 		 root 		 root
# 543 		 aux 		 lwg_vaux
# 544 		 obl 		 k7t
# 545 		 compound 		 lwg__psp
# 546 		 nsubj 		 k1
# 547 		 nmod 		 lwg__psp
# 548 		 amod 		 r6
# 549 		 obj 		 k2
# 550 		 case 		 rsym
# 551 		 obl 		 k7t
# 552 		 case 		 pof__cn
# 553 		 acl:relcl 		 pof__cn
# 554 		 aux 		 pof__cn
# 555 		 aux:pass 		 lwg_vaux
# 556 		 aux:pass 		 lwg_vaux
# 557 		 aux:pass 		 lwg_vaux
# 558 		 punct 		 rsym
# 559 		 start2 		 start2
# 560 		 start1 		 start1
# 561 		 det 		 mod_wq
# 562 		 compound 		 k1
# 563 		 compound 		 lwg__psp
# 564 		 compound 		 r6
# 565 		 obl 		 k7t
# 566 		 case 		 lwg__psp
# 567 		 nsubj 		 k1
# 568 		 obj 		 k2
# 569 		 case 		 nmod__relc
# 570 		 obl 		 start2
# 571 		 case 		 start1
# 572 		 advcl 		 rh
# 573 		 compound 		 k2
# 574 		 aux 		 k7t
# 575 		 root 		 root
# 576 		 aux 		 lwg_vaux
# 577 		 aux:pass 		 lwg_vaux
# 578 		 aux:pass 		 lwg_vaux
# 579 		 punct 		 rsym
# 580 		 start2 		 start2
# 581 		 start1 		 start1
# 582 		 obl 		 k7t
# 583 		 nsubj 		 k1
# 584 		 nmod 		 r6
# 585 		 nmod 		 lwg__psp
# 586 		 case 		 nmod__adj
# 587 		 obl 		 k7t
# 588 		 case 		 lwg__psp
# 589 		 det 		 mod_wq
# 590 		 obj 		 k1
# 591 		 root 		 root
# 592 		 aux 		 lwg_vaux
# 593 		 aux:pass 		 lwg_vaux
# 594 		 aux:pass 		 lwg_vaux
# 595 		 punct 		 rsym
# 596 		 start2 		 start2
# 597 		 start1 		 start1
# 598 		 nsubj 		 k1
# 599 		 nmod 		 nmod__adj
# 600 		 case 		 k1s
# 601 		 obl 		 main
# 602 		 case 		 start2
# 603 		 obj 		 start1
# 604 		 advcl 		 rh
# 605 		 aux 		 k2
# 606 		 compound 		 k7t
# 607 		 root 		 root
# 608 		 aux 		 lwg_vaux
# 609 		 aux:pass 		 lwg_vaux
# 610 		 punct 		 rsym
# 611 		 start2 		 start2
# 612 		 start1 		 start1
# 613 		 nmod 		 nmod__adj
# 614 		 dep 		 k1
# 615 		 det 		 mod_wq
# 616 		 nsubj 		 k1
# 617 		 nsubj 		 k1
# 618 		 nmod 		 r6
# 619 		 case 		 lwg__psp
# 620 		 root 		 root
# 621 		 cop 		 lwg_vaux
# 622 		 nsubj 		 k7t
# 623 		 nmod 		 lwg__psp
# 624 		 case 		 lwg__psp
# 625 		 obl 		 k7t
# 626 		 case 		 lwg__psp
# 627 		 case 		 lwg__psp
# 628 		 obj 		 k2
# 629 		 case 		 lwg__psp
# 630 		 acl:relcl 		 pof
# 631 		 punct 		 rsym
# 632 		 cc 		 k1
# 633 		 nsubj 		 k1
# 634 		 case 		 r6
# 635 		 obl 		 k7t
# 636 		 case 		 lwg__psp
# 637 		 case 		 lwg__psp
# 638 		 det 		 mod_wq
# 639 		 obj 		 k1
# 640 		 conj 		 ccof
# 641 		 aux 		 main
# 642 		 start2 		 start2
# 643 		 start1 		 start1
# 644 		 compound 		 nmod__adj
# 645 		 compound 		 k1
# 646 		 obl 		 k7t
# 647 		 case 		 lwg__psp
# 648 		 compound 		 lwg__psp
# 649 		 nmod 		 pof
# 650 		 case 		 main
# 651 		 obj 		 k2
# 652 		 case 		 lwg__psp
# 653 		 compound 		 pof
# 654 		 obl 		 k7t
# 655 		 mark 		 lwg__psp
# 656 		 compound 		 lwg__psp
# 657 		 root 		 root
# 658 		 aux 		 lwg_vaux
# 659 		 aux:pass 		 lwg_vaux
# 660 		 punct 		 rsym
# 661 		 start2 		 start2
# 662 		 start1 		 start1
# 663 		 nsubj 		 k1
# 664 		 case 		 nmod__adj
# 665 		 root 		 root
# 666 		 mark 		 lwg__psp
# 667 		 compound 		 nmod__adj
# 668 		 compound 		 nmod__adj
# 669 		 compound 		 pof__cn
# 670 		 obl 		 k7t
# 671 		 nmod 		 lwg__psp
# 672 		 punct 		 rsym
# 673 		 dislocated 		 fragof
# 674 		 compound 		 rsym
# 675 		 obl 		 k7t
# 676 		 case 		 pof__cn
# 677 		 case 		 pof__cn
# 678 		 case 		 pof__cn
# 679 		 acl 		 pof__cn
# 680 		 aux:pass 		 lwg_vaux
# 681 		 nmod 		 k7t
# 682 		 case 		 lwg__psp
# 683 		 obj 		 k2
# 684 		 case 		 lwg__psp
# 685 		 compound 		 pof
# 686 		 nmod 		 main
# 687 		 mark 		 lwg__psp
# 688 		 obj 		 k2
# 689 		 case 		 lwg__psp
# 690 		 nummod 		 enm
# 691 		 obl 		 k7t
# 692 		 case 		 lwg__psp
# 693 		 obj 		 k2
# 694 		 aux:pass 		 lwg_vaux
# 695 		 aux:pass 		 lwg_vaux
# 696 		 aux:pass 		 lwg_vaux
# 697 		 punct 		 rsym
# 698 		 start2 		 start2
# 699 		 start1 		 start1
# 700 		 nmod 		 nmod__adj
# 701 		 root 		 root
# 702 		 cop 		 lwg_vaux
# 703 		 mark 		 lwg__psp
# 704 		 compound 		 nmod__adj
# 705 		 nsubj 		 k1
# 706 		 case 		 lwg__psp
# 707 		 compound 		 r6
# 708 		 nmod 		 lwg__psp
# 709 		 case 		 nmod__adj
# 710 		 obl 		 k7t
# 711 		 cc 		 k1
# 712 		 conj 		 ccof
# 713 		 case 		 main
# 714 		 nmod 		 start2
# 715 		 case 		 start1
# 716 		 det 		 mod_wq
# 717 		 compound 		 k1
# 718 		 acl:relcl 		 lwg__psp
# 719 		 aux 		 r6
# 720 		 punct 		 rsym
# 721 		 nmod 		 lwg__psp
# 722 		 nsubj 		 k1
# 723 		 amod 		 lwg__psp
# 724 		 compound 		 r6
# 725 		 obl 		 k7t
# 726 		 case 		 lwg__psp
# 727 		 iobj 		 k4
# 728 		 case 		 lwg__psp
# 729 		 advmod 		 rd
# 730 		 acl 		 lwg__psp
# 731 		 aux 		 lwg__psp
# 732 		 aux:pass 		 lwg_vaux
# 733 		 punct 		 rsym
# 734 		 start2 		 start2
# 735 		 start1 		 start1
# 736 		 nsubj 		 k1
# 737 		 case 		 nmod__adj
# 738 		 obl 		 k7t
# 739 		 compound 		 lwg__psp
# 740 		 compound 		 lwg__psp
# 741 		 obl 		 k7t
# 742 		 case 		 lwg__psp
# 743 		 nmod 		 lwg__psp
# 744 		 case 		 pof
# 745 		 amod 		 main
# 746 		 advmod 		 lwg__vaux
# 747 		 case 		 start2
# 748 		 compound 		 start1
# 749 		 advcl 		 rh
# 750 		 mark 		 lwg__psp
# 751 		 mark 		 lwg__psp
# 752 		 compound 		 pof
# 753 		 iobj 		 k4
# 754 		 case 		 lwg__psp
# 755 		 root 		 root
# 756 		 aux 		 lwg_vaux
# 757 		 punct 		 rsym
# 758 		 start2 		 start2
# 759 		 start1 		 start1
# 760 		 nsubj 		 k1
# 761 		 det 		 mod_wq
# 762 		 compound 		 k1
# 763 		 root 		 root
# 764 		 mark 		 lwg__psp
# 765 		 compound 		 nmod__adj
# 766 		 nmod 		 nmod__adj
# 767 		 case 		 pof__cn
# 768 		 nsubj 		 k1
# 769 		 compound 		 lwg__psp
# 770 		 advcl 		 rh
# 771 		 mark 		 lwg__psp
# 772 		 amod 		 lwg__psp
# 773 		 obl 		 k7t
# 774 		 case 		 lwg__psp
# 775 		 det 		 mod_wq
# 776 		 nsubj 		 k1
# 777 		 acl 		 lwg__psp
# 778 		 cc 		 k1
# 779 		 advmod 		 lwg__psp
# 780 		 det 		 mod_wq
# 781 		 obj 		 k1
# 782 		 nsubj 		 k1
# 783 		 conj 		 ccof
# 784 		 aux 		 main
# 785 		 punct 		 rsym
# 786 		 start2 		 start2
# 787 		 start1 		 start1
# 788 		 nummod 		 enm
# 789 		 amod 		 k7t
# 790 		 obl 		 lwg__psp
# 791 		 case 		 lwg__psp
# 792 		 case 		 pof
# 793 		 obl 		 k7t
# 794 		 case 		 lwg__psp
# 795 		 nmod 		 lwg__psp
# 796 		 case 		 pof
# 797 		 obl 		 k7t
# 798 		 case 		 lwg__psp
# 799 		 nsubj 		 k1
# 800 		 det 		 mod_wq
# 801 		 obj 		 k1
# 802 		 advmod 		 lwg__psp
# 803 		 obj 		 k2
# 804 		 root 		 root
# 805 		 obl 		 lwg_vaux
# 806 		 amod 		 k7t
# 807 		 obl 		 lwg__psp
# 808 		 case 		 lwg__psp
# 809 		 amod 		 pof
# 810 		 compound 		 main
# 811 		 acl:relcl 		 lwg__vaux
# 812 		 punct 		 rsym
# 813 		 start2 		 start2
# 814 		 start1 		 start1
# 815 		 obl 		 k7t
# 816 		 nmod 		 lwg__psp
# 817 		 case 		 lwg__psp
# 818 		 nsubj 		 k1
# 819 		 det 		 mod_wq
# 820 		 obl 		 k1
# 821 		 case 		 lwg__psp
# 822 		 obj 		 k2
# 823 		 case 		 lwg__psp
# 824 		 compound 		 pof
# 825 		 obl 		 k7t
# 826 		 mark 		 lwg__psp
# 827 		 root 		 root
# 828 		 punct 		 rsym
# 829 		 start2 		 start2
# 830 		 start1 		 start1
# 831 		 obl 		 k7t
# 832 		 case 		 lwg__psp
# 833 		 nsubj 		 k1
# 834 		 case 		 lwg__psp
# 835 		 amod 		 r6
# 836 		 compound 		 lwg__psp
# 837 		 dep 		 nmod__adj
# 838 		 root 		 root
# 839 		 aux 		 lwg_vaux
# 840 		 aux:pass 		 lwg_vaux
# 841 		 aux:pass 		 lwg_vaux
# 842 		 punct 		 rsym
# 843 		 start2 		 start2
# 844 		 start1 		 start1
# 845 		 compound 		 nmod__adj
# 846 		 advmod 		 k1
# 847 		 case 		 lwg__psp
# 848 		 amod 		 r6
# 849 		 compound 		 lwg__psp
# 850 		 nsubj 		 k1
# 851 		 case 		 lwg__psp
# 852 		 amod 		 r6
# 853 		 obl 		 k7t
# 854 		 compound 		 lwg__psp
# 855 		 iobj 		 k4
# 856 		 case 		 lwg__psp
# 857 		 compound 		 nmod__adj
# 858 		 compound 		 nmod__adj
# 859 		 compound 		 pof__cn
# 860 		 obl 		 k7t
# 861 		 case 		 lwg__psp
# 862 		 nmod 		 lwg__psp
# 863 		 obj 		 k2
# 864 		 root 		 root
# 865 		 aux 		 lwg_vaux
# 866 		 punct 		 rsym
# 867 		 start2 		 start2
# 868 		 start1 		 start1
# 869 		 mark 		 lwg__psp
# 870 		 obl 		 k7t
# 871 		 case 		 lwg__psp
# 872 		 nmod 		 lwg__psp
# 873 		 case 		 pof
# 874 		 nsubj 		 k1
# 875 		 advcl 		 pof
# 876 		 aux 		 ccof
# 877 		 mark 		 lwg__psp
# 878 		 nsubj 		 k1
# 879 		 amod 		 lwg__psp
# 880 		 compound 		 r6
# 881 		 compound 		 lwg__psp
# 882 		 nmod 		 nmod__adj
# 883 		 case 		 nmod__adj
# 884 		 compound 		 pof__cn
# 885 		 root 		 root
# 886 		 aux 		 lwg_vaux
# 887 		 punct 		 rsym
# 888 		 start2 		 start2
# 889 		 start1 		 start1
# 890 		 amod 		 nmod__adj
# 891 		 compound 		 k1
# 892 		 compound 		 lwg__psp
# 893 		 nsubj 		 k1
# 894 		 nummod 		 enm
# 895 		 advmod 		 k7t
# 896 		 root 		 root
# 897 		 cop 		 lwg_vaux
# 898 		 punct 		 rsym
# 899 		 start2 		 start2
# 900 		 start1 		 start1
# 901 		 det 		 mod_wq
# 902 		 compound 		 k1
# 903 		 nsubj 		 k1
# 904 		 case 		 r6
# 905 		 compound 		 lwg__psp
# 906 		 compound 		 nmod__adj
# 907 		 nmod 		 nmod__adj
# 908 		 case 		 pof__cn
# 909 		 amod 		 k1
# 910 		 amod 		 lwg__psp
# 911 		 nummod 		 enm
# 912 		 nmod 		 k7t
# 913 		 case 		 lwg__psp
# 914 		 obj 		 k2
# 915 		 nmod 		 lwg__psp
# 916 		 mark 		 lwg__psp
# 917 		 compound 		 pof
# 918 		 advmod 		 main
# 919 		 root 		 root
# 920 		 aux 		 lwg_vaux
# 921 		 cc 		 k1
# 922 		 nsubj 		 k1
# 923 		 conj 		 ccof
# 924 		 aux 		 main
# 925 		 mark 		 lwg__psp
# 926 		 compound 		 nmod__adj
# 927 		 nsubj 		 k1
# 928 		 case 		 lwg__psp
# 929 		 case 		 r6
# 930 		 nummod 		 enm
# 931 		 obl 		 k7t
# 932 		 case 		 lwg__psp
# 933 		 case 		 lwg__psp
# 934 		 case 		 pof
# 935 		 nummod 		 enm
# 936 		 obj 		 k7t
# 937 		 obj 		 k2
# 938 		 aux 		 nmod__relc
# 939 		 aux:pass 		 lwg_vaux
# 940 		 punct 		 rsym
# 941 		 start2 		 start2
# 942 		 start1 		 start1
# 943 		 nmod 		 nmod__adj
# 944 		 root 		 root
# 945 		 cop 		 lwg_vaux
# 946 		 mark 		 lwg__psp
# 947 		 obj 		 k2
# 948 		 cc 		 k1
# 949 		 amod 		 lwg__rp
# 950 		 conj 		 ccof
# 951 		 case 		 lwg__vaux
# 952 		 obl 		 k7t
# 953 		 mark 		 lwg__psp
# 954 		 mark 		 lwg__psp
# 955 		 mark 		 lwg__psp
# 956 		 nmod 		 pof
# 957 		 case 		 main
# 958 		 amod 		 lwg__vaux
# 959 		 nsubj 		 start2
# 960 		 nsubj 		 start1
# 961 		 nummod 		 enm
# 962 		 xcomp 		 k2
# 963 		 advcl 		 lwg__psp
# 964 		 aux 		 pof
# 965 		 mark 		 lwg__psp
# 966 		 obl 		 k7t
# 967 		 case 		 lwg__psp
# 968 		 case 		 lwg__psp
# 969 		 amod 		 pof
# 970 		 nsubj 		 k1
# 971 		 advmod 		 pof
# 972 		 acl 		 ccof
# 973 		 punct 		 rsym
# 974 		 start2 		 start2
# 975 		 start1 		 start1
# 976 		 compound 		 nmod__adj
# 977 		 nsubj 		 k1
# 978 		 obl 		 k7t
# 979 		 compound 		 lwg__psp
# 980 		 xcomp 		 k2
# 981 		 root 		 root
# 982 		 aux 		 lwg_vaux
# 983 		 aux:pass 		 lwg_vaux
# 984 		 punct 		 rsym
# 985 		 start2 		 start2
# 986 		 start1 		 start1
# 987 		 nmod 		 nmod__adj
# 988 		 dep 		 k1
# 989 		 nummod 		 enm
# 990 		 advmod 		 k7t
# 991 		 amod 		 lwg__psp
# 992 		 obl 		 k7t
# 993 		 case 		 lwg__psp
# 994 		 nsubj 		 k1
# 995 		 obl 		 k7t
# 996 		 case 		 lwg__psp
# 997 		 compound 		 lwg__psp
# 998 		 obl 		 k7t
# 999 		 case 		 lwg__psp
# 1000 		 dep 		 lwg__psp
# 1001 		 det 		 mod_wq
# 1002 		 obj 		 k1
# 1003 		 root 		 root
# 1004 		 aux 		 lwg_vaux
# 1005 		 punct 		 rsym
# 1006 		 start2 		 start2
# 1007 		 start1 		 start1
# 1008 		 compound 		 nmod__adj
# 1009 		 compound 		 k1
# 1010 		 compound 		 lwg__psp
# 1011 		 nmod 		 r6
# 1012 		 case 		 lwg__psp
# 1013 		 root 		 root
# 1014 		 cop 		 lwg_vaux
# 1015 		 cc 		 k1
# 1016 		 det 		 mod_wq
# 1017 		 obl 		 k1
# 1018 		 case 		 lwg__psp
# 1019 		 obl 		 k7t
# 1020 		 mark 		 lwg__psp
# 1021 		 mark 		 lwg__psp
# 1022 		 dep 		 pof
# 1023 		 nsubj 		 k1
# 1024 		 nmod 		 pof
# 1025 		 obl 		 k7t
# 1026 		 case 		 lwg__psp
# 1027 		 conj 		 ccof
# 1028 		 aux 		 main
# 1029 		 aux:pass 		 lwg_vaux
# 1030 		 punct 		 rsym
# 1031 		 start2 		 start2
# 1032 		 start1 		 start1
# 1033 		 obl 		 k7t
# 1034 		 dep 		 lwg__psp
# 1035 		 case 		 lwg__psp
# 1036 		 nsubj 		 k1
# 1037 		 nmod 		 lwg__psp
# 1038 		 nummod 		 enm
# 1039 		 det 		 mod_wq
# 1040 		 obl 		 k1
# 1041 		 case 		 lwg__psp
# 1042 		 case 		 r6
# 1043 		 case 		 lwg__psp
# 1044 		 root 		 root
# 1045 		 obj 		 lwg_vaux
# 1046 		 nsubj 		 k7t
# 1047 		 advcl 		 lwg__psp
# 1048 		 dep 		 lwg__psp
# 1049 		 advmod 		 rd
# 1050 		 acl:relcl 		 lwg__psp
# 1051 		 aux 		 lwg__psp
# 1052 		 aux:pass 		 lwg_vaux
# 1053 		 punct 		 rsym
# 1054 		 start2 		 start2
# 1055 		 start1 		 start1
# 1056 		 obl 		 k7t
# 1057 		 dep 		 lwg__psp
# 1058 		 case 		 lwg__psp
# 1059 		 nummod 		 enm
# 1060 		 obl 		 k7t
# 1061 		 case 		 lwg__psp
# 1062 		 case 		 lwg__psp
# 1063 		 iobj 		 k4
# 1064 		 obl 		 lwg__psp
# 1065 		 root 		 root
# 1066 		 aux:pass 		 lwg_vaux
# 1067 		 mark 		 lwg__psp
# 1068 		 det 		 mod_wq
# 1069 		 det 		 mod_wq
# 1070 		 amod 		 k1
# 1071 		 obj 		 k2
# 1072 		 nsubj 		 k1
# 1073 		 nsubj 		 k1
# 1074 		 advcl 		 r6
# 1075 		 dep 		 lwg__psp
# 1076 		 advmod 		 rd
# 1077 		 obj 		 lwg__psp
# 1078 		 aux 		 lwg__psp
# 1079 		 aux:pass 		 lwg_vaux
# 1080 		 punct 		 rsym
# 1081 		 start2 		 start2
# 1082 		 start1 		 start1
# 1083 		 nsubj 		 k1
# 1084 		 root 		 root
# 1085 		 mark 		 lwg__psp
# 1086 		 nsubj 		 k1
# 1087 		 obl 		 k7t
# 1088 		 case 		 lwg__psp
# 1089 		 case 		 lwg__psp
# 1090 		 case 		 pof
# 1091 		 obj 		 k2
# 1092 		 obj 		 k2
# 1093 		 aux 		 pof
# 1094 		 punct 		 rsym
# 1095 		 start2 		 start2
# 1096 		 start1 		 start1
# 1097 		 nmod 		 nmod__adj
# 1098 		 mark 		 lwg__psp
# 1099 		 nmod 		 nmod__adj
# 1100 		 case 		 nmod__adj
# 1101 		 nsubj 		 k1
# 1102 		 nmod 		 lwg__psp
# 1103 		 cc 		 k1
# 1104 		 conj 		 ccof
# 1105 		 case 		 main
# 1106 		 nmod 		 start2
# 1107 		 cop 		 start1
# 1108 		 mark 		 lwg__psp
# 1109 		 nmod 		 nmod__adj
# 1110 		 amod 		 nmod__adj
# 1111 		 nsubj 		 k1
# 1112 		 root 		 root
# 1113 		 punct 		 rsym
# 1114 		 start2 		 start2
# 1115 		 start1 		 start1
# 1116 		 nsubj 		 k1
# 1117 		 root 		 root
# 1118 		 mark 		 lwg__psp
# 1119 		 nmod 		 nmod__adj
# 1120 		 case 		 nmod__adj
# 1121 		 nmod 		 pof__cn
# 1122 		 case 		 k1
# 1123 		 nmod 		 lwg__psp
# 1124 		 case 		 r6
# 1125 		 case 		 lwg__psp
# 1126 		 compound 		 nmod__adj
# 1127 		 obj 		 k2
# 1128 		 punct 		 rsym
# 1129 		 start2 		 start2
# 1130 		 start1 		 start1
# 1131 		 nsubj 		 k1
# 1132 		 case 		 nmod__adj
# 1133 		 obj 		 k2
# 1134 		 dep 		 lwg__psp
# 1135 		 root 		 root
# 1136 		 mark 		 lwg__psp
# 1137 		 nsubj 		 k1
# 1138 		 compound 		 lwg__psp
# 1139 		 obl 		 k7t
# 1140 		 case 		 lwg__psp
# 1141 		 case 		 lwg__psp
# 1142 		 nmod 		 pof
# 1143 		 case 		 main
# 1144 		 compound 		 lwg__vaux
# 1145 		 acl 		 start2
# 1146 		 aux 		 start1
# 1147 		 punct 		 rsym
# 1148 		 obj 		 rsym
# 1149 		 obl 		 k7t
# 1150 		 mark 		 lwg__psp
# 1151 		 compound 		 lwg__psp
# 1152 		 conj 		 ccof
# 1153 		 aux 		 main
# 1154 		 punct 		 rsym
# 1155 		 det 		 mod_wq
# 1156 		 nsubj 		 k1
# 1157 		 case 		 lwg__psp
# 1158 		 acl 		 r6
# 1159 		 aux 		 lwg__psp
# 1160 		 punct 		 rsym
# 1161 		 start2 		 start2
# 1162 		 start1 		 start1
# 1163 		 det 		 mod_wq
# 1164 		 obl 		 k1
# 1165 		 nmod 		 lwg__psp
# 1166 		 case 		 r6
# 1167 		 compound 		 lwg__psp
# 1168 		 root 		 root
# 1169 		 mark 		 lwg__psp
# 1170 		 nsubj 		 k1
# 1171 		 nummod 		 enm
# 1172 		 nmod 		 k7t
# 1173 		 case 		 lwg__psp
# 1174 		 nmod 		 lwg__psp
# 1175 		 nmod 		 pof
# 1176 		 case 		 main
# 1177 		 case 		 lwg__vaux
# 1178 		 obl 		 k7t
# 1179 		 cop 		 k1
# 1180 		 punct 		 rsym
# 1181 		 start2 		 start2
# 1182 		 start1 		 start1
# 1183 		 nsubj 		 k1
# 1184 		 compound 		 nmod__adj
# 1185 		 nmod 		 k1s
# 1186 		 case 		 main
# 1187 		 compound 		 start2
# 1188 		 compound 		 start1
# 1189 		 compound 		 nmod__adj
# 1190 		 obl 		 k7t
# 1191 		 case 		 lwg__psp
# 1192 		 compound 		 lwg__psp
# 1193 		 root 		 root
# 1194 		 punct 		 rsym
# 1195 		 start2 		 start2
# 1196 		 start1 		 start1
# 1197 		 nmod 		 nmod__adj
# 1198 		 nmod 		 k1
# 1199 		 case 		 lwg__psp
# 1200 		 compound 		 r6
# 1201 		 root 		 root
# 1202 		 cc 		 k1
# 1203 		 compound 		 lwg__psp
# 1204 		 conj 		 ccof
# 1205 		 dep 		 main
# 1206 		 cop 		 start2
# 1207 		 punct 		 rsym
# 1208 		 start2 		 start2
# 1209 		 start1 		 start1
# 1210 		 nsubj 		 k1
# 1211 		 case 		 nmod__adj
# 1212 		 nmod 		 k1s
# 1213 		 case 		 main
# 1214 		 obj 		 k2
# 1215 		 nmod 		 lwg__psp
# 1216 		 compound 		 pof
# 1217 		 obl 		 k7t
# 1218 		 case 		 lwg__psp
# 1219 		 case 		 lwg__psp
# 1220 		 advcl 		 rh
# 1221 		 nmod 		 lwg__psp
# 1222 		 amod 		 lwg__psp
# 1223 		 obl 		 k7t
# 1224 		 case 		 lwg__psp
# 1225 		 obj 		 k2
# 1226 		 advcl 		 lwg__psp
# 1227 		 nmod 		 pof
# 1228 		 nmod 		 main
# 1229 		 cc 		 k1
# 1230 		 nmod 		 lwg__psp
# 1231 		 case 		 r6
# 1232 		 nmod 		 lwg__psp
# 1233 		 case 		 nmod__adj
# 1234 		 nsubj 		 k1
# 1235 		 root 		 root
# 1236 		 case 		 lwg_vaux
# 1237 		 cop 		 k7t
# 1238 		 punct 		 rsym
# 1239 		 start2 		 start2
# 1240 		 start1 		 start1
# 1241 		 nmod 		 nmod__adj
# 1242 		 obj 		 k2
# 1243 		 obl 		 k7t
# 1244 		 case 		 lwg__psp
# 1245 		 advmod 		 rd
# 1246 		 root 		 root
# 1247 		 aux:pass 		 lwg_vaux
# 1248 		 punct 		 rsym
# 1249 		 advmod 		 rsym
# 1250 		 mark 		 lwg__psp
# 1251 		 det 		 mod_wq
# 1252 		 nsubj 		 k1
# 1253 		 obj 		 k2
# 1254 		 case 		 nmod__relc
# 1255 		 advmod 		 start2
# 1256 		 advcl 		 start1
# 1257 		 aux 		 nmod__adj
# 1258 		 punct 		 rsym
# 1259 		 start2 		 start2
# 1260 		 start1 		 start1
# 1261 		 nummod 		 enm
# 1262 		 obj 		 k7t
# 1263 		 advcl 		 lwg__psp
# 1264 		 aux 		 lwg__psp
# 1265 		 punct 		 rsym
# 1266 		 mark 		 lwg__psp
# 1267 		 advcl 		 rh
# 1268 		 advmod 		 lwg__psp
# 1269 		 root 		 root
# 1270 		 punct 		 rsym
# 1271 		 start2 		 start2
# 1272 		 start1 		 start1
# 1273 		 obl 		 k7t
# 1274 		 dep 		 lwg__psp
# 1275 		 obl 		 k7t
# 1276 		 case 		 lwg__psp
# 1277 		 nmod 		 lwg__psp
# 1278 		 case 		 pof
# 1279 		 det 		 mod_wq
# 1280 		 nsubj 		 k1
# 1281 		 root 		 root
# 1282 		 aux 		 lwg_vaux
# 1283 		 punct 		 rsym
# 1284 		 cc 		 k1
# 1285 		 nsubj 		 k1
# 1286 		 dep 		 r6
# 1287 		 nmod 		 lwg__psp
# 1288 		 obl 		 k7t
# 1289 		 case 		 lwg__psp
# 1290 		 obj 		 k2
# 1291 		 conj 		 ccof
# 1292 		 punct 		 rsym
# 1293 		 start2 		 start2
# 1294 		 start1 		 start1
# 1295 		 nmod 		 nmod__adj
# 1296 		 case 		 k1
# 1297 		 obj 		 k2
# 1298 		 obl 		 k7t
# 1299 		 nsubj 		 k1
# 1300 		 dep 		 r6
# 1301 		 root 		 root
# 1302 		 punct 		 rsym
# 1303 		 start2 		 start2
# 1304 		 start1 		 start1
# 1305 		 nmod 		 nmod__adj
# 1306 		 nmod 		 k1
# 1307 		 case 		 lwg__psp
# 1308 		 compound 		 r6
# 1309 		 amod 		 lwg__psp
# 1310 		 mark 		 lwg__psp
# 1311 		 punct 		 rsym
# 1312 		 amod 		 rsym
# 1313 		 mark 		 lwg__psp
# 1314 		 nmod 		 lwg__psp
# 1315 		 case 		 pof
# 1316 		 amod 		 main
# 1317 		 root 		 root
# 1318 		 cop 		 lwg_vaux
# 1319 		 punct 		 rsym
# 1320 		 start2 		 start2
# 1321 		 start1 		 start1
# 1322 		 nsubj 		 k1
# 1323 		 det 		 mod_wq
# 1324 		 root 		 root
# 1325 		 cop 		 lwg_vaux
# 1326 		 punct 		 rsym
# 1327 		 start2 		 start2
# 1328 		 start1 		 start1
# 1329 		 nsubj 		 k1
# 1330 		 nsubj 		 k1
# 1331 		 nmod 		 r6
# 1332 		 case 		 lwg__psp
# 1333 		 compound 		 nmod__adj
# 1334 		 advmod 		 nmod__adj
# 1335 		 root 		 root
# 1336 		 punct 		 rsym
# 1337 		 start2 		 start2
# 1338 		 start1 		 start1
# 1339 		 nsubj 		 k1
# 1340 		 advcl 		 nmod__adj
# 1341 		 punct 		 rsym
# 1342 		 mark 		 lwg__psp
# 1343 		 obl 		 k7t
# 1344 		 root 		 root
# 1345 		 dep 		 lwg_vaux
# 1346 		 aux 		 k7t
# 1347 		 aux:pass 		 lwg_vaux
# 1348 		 punct 		 rsym
# 1349 		 start2 		 start2
# 1350 		 start1 		 start1
# 1351 		 nsubj 		 k1
# 1352 		 cc 		 k1
# 1353 		 conj 		 ccof
# 1354 		 nummod 		 enm
# 1355 		 amod 		 k7t
# 1356 		 root 		 root
# 1357 		 cop 		 lwg_vaux
# 1358 		 punct 		 rsym
# 1359 		 start2 		 start2
# 1360 		 start1 		 start1
# 1361 		 nmod 		 nmod__adj
# 1362 		 case 		 k1
# 1363 		 nsubj 		 k1
# 1364 		 nsubj 		 k1
# 1365 		 cc 		 k1
# 1366 		 conj 		 ccof
# 1367 		 nummod 		 enm
# 1368 		 amod 		 k7t
# 1369 		 obl 		 lwg__psp
# 1370 		 case 		 lwg__psp
# 1371 		 root 		 root
# 1372 		 punct 		 rsym
# 1373 		 start2 		 start2
# 1374 		 start1 		 start1
# 1375 		 nummod 		 enm
# 1376 		 nsubj 		 k7t
# 1377 		 obl 		 lwg__psp
# 1378 		 case 		 lwg__psp
# 1379 		 case 		 pof
# 1380 		 obl 		 k7t
# 1381 		 case 		 lwg__psp
# 1382 		 dep 		 lwg__psp
# 1383 		 obl 		 k7t
# 1384 		 cc 		 k1
# 1385 		 conj 		 ccof
# 1386 		 case 		 main
# 1387 		 root 		 root
# 1388 		 aux 		 lwg_vaux
# 1389 		 punct 		 rsym
# 1390 		 start2 		 start2
# 1391 		 start1 		 start1
# 1392 		 iobj 		 k4
# 1393 		 case 		 lwg__psp
# 1394 		 nsubj 		 k1
# 1395 		 root 		 root
# 1396 		 punct 		 rsym
# 1397 		 start2 		 start2
# 1398 		 start1 		 start1
# 1399 		 advmod 		 nmod__adj
# 1400 		 compound 		 k1
# 1401 		 obl 		 k7t
# 1402 		 case 		 lwg__psp
# 1403 		 compound 		 lwg__psp
# 1404 		 root 		 root
# 1405 		 punct 		 rsym
# 1406 		 start2 		 start2
# 1407 		 start1 		 start1
# 1408 		 amod 		 nmod__adj
# 1409 		 obj 		 k2
# 1410 		 advcl 		 lwg__psp
# 1411 		 compound 		 pof
# 1412 		 root 		 root
# 1413 		 cc 		 k1
# 1414 		 amod 		 lwg__psp
# 1415 		 obl 		 k7t
# 1416 		 case 		 lwg__psp
# 1417 		 conj 		 ccof
# 1418 		 aux 		 main
# 1419 		 aux:pass 		 lwg_vaux
# 1420 		 punct 		 rsym
# 1421 		 start2 		 start2
# 1422 		 start1 		 start1
# 1423 		 obl 		 k7t
# 1424 		 obl 		 lwg__psp
# 1425 		 case 		 lwg__psp
# 1426 		 nsubj 		 k1
# 1427 		 root 		 root
# 1428 		 cc 		 k1
# 1429 		 nsubj 		 k1
# 1430 		 case 		 r6
# 1431 		 amod 		 lwg__psp
# 1432 		 obl 		 k7t
# 1433 		 case 		 lwg__psp
# 1434 		 case 		 lwg__psp
# 1435 		 advmod 		 rd
# 1436 		 compound 		 lwg__psp
# 1437 		 obl 		 k7t
# 1438 		 case 		 lwg__psp
# 1439 		 case 		 lwg__psp
# 1440 		 compound 		 pof
# 1441 		 conj 		 ccof
# 1442 		 aux 		 lwg__vaux
# 1443 		 start2 		 start2
# 1444 		 start1 		 start1
# 1445 		 obl 		 k7t
# 1446 		 case 		 lwg__psp
# 1447 		 obj 		 k2
# 1448 		 advcl 		 lwg__psp
# 1449 		 det 		 mod_wq
# 1450 		 dep 		 k1
# 1451 		 amod 		 lwg__psp
# 1452 		 punct 		 rsym
# 1453 		 nsubj 		 k1
# 1454 		 acl:relcl 		 nmod__adj
# 1455 		 aux 		 k1s
# 1456 		 punct 		 rsym
# 1457 		 obj 		 r6
# 1458 		 nsubj 		 k1
# 1459 		 case 		 lwg__rp
# 1460 		 advcl 		 nmod__adj
# 1461 		 advmod 		 k1s
# 1462 		 root 		 root
# 1463 		 punct 		 rsym
# 1464 		 start2 		 start2
# 1465 		 start1 		 start1
# 1466 		 obl 		 k7t
# 1467 		 nmod 		 lwg__psp
# 1468 		 obj 		 k2
# 1469 		 case 		 lwg__psp
# 1470 		 advcl 		 rh
# 1471 		 nummod 		 enm
# 1472 		 obl 		 k7t
# 1473 		 case 		 lwg__psp
# 1474 		 case 		 lwg__psp
# 1475 		 nmod 		 pof
# 1476 		 nsubj 		 k1
# 1477 		 compound 		 pof
# 1478 		 root 		 root
# 1479 		 aux 		 lwg_vaux
# 1480 		 punct 		 rsym
# 1481 		 start2 		 start2
# 1482 		 start1 		 start1
# 1483 		 obl 		 k7t
# 1484 		 nsubj 		 k1
# 1485 		 punct 		 rsym
# 1486 		 root 		 root
# 1487 		 aux 		 lwg_vaux
# 1488 		 punct 		 rsym
# 1489 		 nmod 		 rsym
# 1490 		 case 		 rsym
# 1491 		 nsubj 		 k1
# 1492 		 advcl 		 nmod__adj
# 1493 		 nmod 		 k1s
# 1494 		 case 		 main
# 1495 		 nsubj 		 k1
# 1496 		 obl 		 k7t
# 1497 		 cop 		 lwg__psp
# 1498 		 punct 		 rsym
# 1499 		 advmod 		 rsym
# 1500 		 nsubj 		 k1
# 1501 		 det 		 mod_wq
# 1502 		 amod 		 k1
# 1503 		 compound 		 lwg__psp
# 1504 		 advmod 		 rd
# 1505 		 acl:relcl 		 lwg__psp
# 1506 		 aux 		 lwg__psp
# 1507 		 punct 		 rsym
# 1508 		 obl 		 k7t
# 1509 		 nsubj 		 k1
# 1510 		 nmod 		 r6
# 1511 		 case 		 lwg__psp
# 1512 		 obj 		 k2
# 1513 		 obl 		 k7t
# 1514 		 case 		 lwg__psp
# 1515 		 case 		 lwg__psp
# 1516 		 obj 		 k2
# 1517 		 aux 		 lwg__psp
# 1518 		 aux:pass 		 lwg_vaux
# 1519 		 punct 		 rsym
# 1520 		 start2 		 start2
# 1521 		 start1 		 start1
# 1522 		 nmod 		 nmod__adj
# 1523 		 case 		 k1
# 1524 		 obj 		 k2
# 1525 		 case 		 nmod__relc
# 1526 		 nmod 		 start2
# 1527 		 case 		 start1
# 1528 		 obl 		 k7t
# 1529 		 case 		 lwg__psp
# 1530 		 obj 		 k2
# 1531 		 aux 		 lwg__psp
# 1532 		 root 		 root
# 1533 		 aux 		 lwg_vaux
# 1534 		 punct 		 rsym
# 1535 		 start2 		 start2
# 1536 		 start1 		 start1
# 1537 		 nsubj 		 k1
# 1538 		 case 		 nmod__adj
# 1539 		 amod 		 k1s
# 1540 		 obl 		 main
# 1541 		 case 		 start2
# 1542 		 advcl 		 start1
# 1543 		 nsubj 		 k1
# 1544 		 advmod 		 nmod__adj
# 1545 		 root 		 root
# 1546 		 aux 		 lwg_vaux
# 1547 		 aux:pass 		 lwg_vaux
# 1548 		 start2 		 start2
# 1549 		 start1 		 start1
# 1550 		 obj 		 k2
# 1551 		 dep 		 lwg__psp
# 1552 		 advcl 		 rh
# 1553 		 mark 		 lwg__psp
# 1554 		 mark 		 lwg__psp
# 1555 		 det 		 mod_wq
# 1556 		 nsubj 		 k1
# 1557 		 advmod 		 lwg__psp
# 1558 		 root 		 root
# 1559 		 punct 		 rsym
# 1560 		 start2 		 start2
# 1561 		 start1 		 start1
# 1562 		 nsubj 		 k1
# 1563 		 case 		 nmod__adj
# 1564 		 root 		 root
# 1565 		 obl 		 lwg_vaux
# 1566 		 punct 		 rsym
# 1567 		 obl 		 k7t
# 1568 		 case 		 pof__cn
# 1569 		 dep 		 pof__cn
# 1570 		 nmod 		 pof__cn
# 1571 		 case 		 pof__cn
# 1572 		 nsubj 		 k1
# 1573 		 advmod 		 lwg__psp
# 1574 		 punct 		 rsym
# 1575 		 nmod 		 rsym
# 1576 		 mark 		 lwg__psp
# 1577 		 obl 		 k7t
# 1578 		 case 		 lwg__psp
# 1579 		 case 		 lwg__psp
# 1580 		 det 		 mod_wq
# 1581 		 det 		 mod_wq
# 1582 		 nsubj 		 k1
# 1583 		 obj 		 k2
# 1584 		 punct 		 rsym
# 1585 		 start2 		 start2
# 1586 		 start1 		 start1
# 1587 		 punct 		 rsym
# 1588 		 nsubj 		 k1
# 1589 		 root 		 root
# 1590 		 aux 		 lwg_vaux
# 1591 		 punct 		 rsym
# 1592 		 nsubj 		 k1
# 1593 		 compound 		 nmod__adj
# 1594 		 dep 		 k1s
# 1595 		 advcl 		 main
# 1596 		 aux 		 start2
# 1597 		 punct 		 rsym
# 1598 		 mark 		 lwg__psp
# 1599 		 nmod 		 lwg__psp
# 1600 		 obl 		 k7t
# 1601 		 case 		 lwg__psp
# 1602 		 case 		 lwg__psp
# 1603 		 nsubj 		 k1
# 1604 		 case 		 lwg__psp
# 1605 		 obl 		 k7t
# 1606 		 case 		 lwg__psp
# 1607 		 advcl 		 rh
# 1608 		 dep 		 lwg__psp
# 1609 		 aux 		 lwg__psp
# 1610 		 punct 		 rsym
# 1611 		 start2 		 start2
# 1612 		 start1 		 start1
# 1613 		 nsubj 		 k1
# 1614 		 case 		 nmod__adj
# 1615 		 amod 		 k1s
# 1616 		 compound 		 main
# 1617 		 root 		 root
# 1618 		 punct 		 rsym
# 1619 		 cc 		 k1
# 1620 		 nsubj 		 k1
# 1621 		 case 		 r6
# 1622 		 obj 		 k2
# 1623 		 advmod 		 rsym
# 1624 		 conj 		 ccof
# 1625 		 start2 		 start2
# 1626 		 start1 		 start1
# 1627 		 compound 		 nmod__adj
# 1628 		 compound 		 k1
# 1629 		 compound 		 lwg__psp
# 1630 		 nsubj 		 k1
# 1631 		 case 		 lwg__psp
# 1632 		 obl 		 k7t
# 1633 		 dep 		 lwg__psp
# 1634 		 case 		 lwg__psp
# 1635 		 nmod 		 pof
# 1636 		 compound 		 main
# 1637 		 compound 		 lwg__vaux
# 1638 		 obj 		 k2
# 1639 		 obl 		 k7t
# 1640 		 case 		 lwg__psp
# 1641 		 compound 		 lwg__psp
# 1642 		 root 		 root
# 1643 		 aux 		 lwg_vaux
# 1644 		 cc 		 k1
# 1645 		 nmod 		 lwg__psp
# 1646 		 nummod 		 enm
# 1647 		 obj 		 k7t
# 1648 		 compound 		 lwg__psp
# 1649 		 conj 		 ccof
# 1650 		 aux:pass 		 lwg_vaux
# 1651 		 aux:pass 		 lwg_vaux
# 1652 		 punct 		 rsym
# 1653 		 start2 		 start2
# 1654 		 start1 		 start1
# 1655 		 obl 		 k7t
# 1656 		 compound 		 lwg__psp
# 1657 		 compound 		 lwg__psp
# 1658 		 nummod 		 enm
# 1659 		 compound 		 k7t
# 1660 		 nmod 		 lwg__psp
# 1661 		 case 		 lwg__psp
# 1662 		 obj 		 k2
# 1663 		 obl 		 k7t
# 1664 		 case 		 lwg__psp
# 1665 		 case 		 lwg__psp
# 1666 		 nummod 		 enm
# 1667 		 nmod 		 k7t
# 1668 		 cc 		 k1
# 1669 		 compound 		 r6
# 1670 		 conj 		 ccof
# 1671 		 nummod 		 enm
# 1672 		 nmod 		 k7t
# 1673 		 nummod 		 enm
# 1674 		 conj 		 ccof
# 1675 		 case 		 lwg__vaux
# 1676 		 obj 		 k2
# 1677 		 nummod 		 enm
# 1678 		 acl 		 k7t
# 1679 		 root 		 root
# 1680 		 aux:pass 		 lwg_vaux
# 1681 		 aux:pass 		 lwg_vaux
# 1682 		 punct 		 rsym
# 1683 		 start2 		 start2
# 1684 		 start1 		 start1
# 1685 		 amod 		 nmod__adj
# 1686 		 dep 		 k1
# 1687 		 root 		 root
# 1688 		 cop 		 lwg_vaux
# 1689 		 mark 		 lwg__psp
# 1690 		 obj 		 k2
# 1691 		 dep 		 lwg__psp
# 1692 		 compound 		 pof
# 1693 		 compound 		 main
# 1694 		 obj 		 k2
# 1695 		 advmod 		 lwg__psp
# 1696 		 acl 		 pof
# 1697 		 aux:pass 		 lwg_vaux
# 1698 		 aux:pass 		 lwg_vaux
# 1699 		 cc 		 k1
# 1700 		 compound 		 lwg__psp
# 1701 		 compound 		 r6
# 1702 		 obj 		 k2
# 1703 		 case 		 rsym
# 1704 		 obl 		 k7t
# 1705 		 case 		 pof__cn
# 1706 		 advcl 		 rh
# 1707 		 aux 		 lwg__psp
# 1708 		 compound 		 lwg__psp
# 1709 		 conj 		 ccof
# 1710 		 aux:pass 		 lwg_vaux
# 1711 		 aux:pass 		 lwg_vaux
# 1712 		 punct 		 rsym
# 1713 		 start2 		 start2
# 1714 		 start1 		 start1
# 1715 		 compound 		 nmod__adj
# 1716 		 compound 		 k1
# 1717 		 obl 		 k7t
# 1718 		 case 		 lwg__psp
# 1719 		 nsubj 		 k1
# 1720 		 det 		 mod_wq
# 1721 		 nmod 		 k1
# 1722 		 case 		 lwg__psp
# 1723 		 obl 		 k7t
# 1724 		 case 		 lwg__psp
# 1725 		 punct 		 rsym
# 1726 		 compound 		 rsym
# 1727 		 nmod 		 rsym
# 1728 		 punct 		 rsym
# 1729 		 obj 		 rsym
# 1730 		 root 		 root
# 1731 		 aux 		 lwg_vaux
# 1732 		 aux:pass 		 lwg_vaux
# 1733 		 punct 		 rsym
# 1734 		 start2 		 start2
# 1735 		 start1 		 start1
# 1736 		 obl 		 k7t
# 1737 		 case 		 lwg__psp
# 1738 		 nmod 		 lwg__psp
# 1739 		 case 		 pof
# 1740 		 nmod 		 main
# 1741 		 obj 		 k2
# 1742 		 compound 		 lwg__psp
# 1743 		 compound 		 pof
# 1744 		 compound 		 main
# 1745 		 compound 		 lwg__vaux
# 1746 		 iobj 		 k4
# 1747 		 case 		 lwg__psp
# 1748 		 root 		 root
# 1749 		 aux 		 lwg_vaux
# 1750 		 aux:pass 		 lwg_vaux
# 1751 		 punct 		 rsym
# 1752 		 obl 		 k7t
# 1753 		 compound 		 pof__cn
# 1754 		 obl 		 k7t
# 1755 		 case 		 lwg__psp
# 1756 		 dep 		 lwg__psp
# 1757 		 nummod 		 enm
# 1758 		 nmod 		 k7t
# 1759 		 case 		 lwg__psp
# 1760 		 nsubj 		 k1
# 1761 		 acl:relcl 		 lwg__psp
# 1762 		 aux 		 r6
# 1763 		 aux:pass 		 lwg_vaux
# 1764 		 punct 		 rsym
# 1765 		 start2 		 start2
# 1766 		 start1 		 start1
# 1767 		 det 		 mod_wq
# 1768 		 obj 		 k1
# 1769 		 det 		 mod_wq
# 1770 		 nummod 		 enm
# 1771 		 compound 		 k7t
# 1772 		 obl 		 lwg__psp
# 1773 		 case 		 lwg__psp
# 1774 		 root 		 root
# 1775 		 aux:pass 		 lwg_vaux
# 1776 		 aux:pass 		 lwg_vaux
# 1777 		 aux:pass 		 lwg_vaux
# 1778 		 punct 		 rsym
# 1779 		 start2 		 start2
# 1780 		 start1 		 start1
# 1781 		 nummod 		 enm
# 1782 		 nsubj 		 k7t
# 1783 		 det 		 mod_wq
# 1784 		 obl 		 k1
# 1785 		 case 		 lwg__psp
# 1786 		 compound 		 r6
# 1787 		 advcl 		 lwg__psp
# 1788 		 compound 		 nmod__adj
# 1789 		 advcl 		 rh
# 1790 		 aux 		 lwg__psp
# 1791 		 obl 		 k7t
# 1792 		 case 		 lwg__psp
# 1793 		 case 		 lwg__psp
# 1794 		 compound 		 pof
# 1795 		 compound 		 main
# 1796 		 obl 		 k7t
# 1797 		 case 		 lwg__psp
# 1798 		 root 		 root
# 1799 		 aux 		 lwg_vaux
# 1800 		 aux:pass 		 lwg_vaux
# 1801 		 mark 		 lwg__psp
# 1802 		 obl 		 k7t
# 1803 		 punct 		 rsym
# 1804 		 nsubj 		 k1
# 1805 		 case 		 nmod__adj
# 1806 		 obl 		 k7t
# 1807 		 case 		 lwg__psp
# 1808 		 iobj 		 k4
# 1809 		 case 		 lwg__psp
# 1810 		 obj 		 k2
# 1811 		 dep 		 lwg__psp
# 1812 		 advcl 		 rh
# 1813 		 aux 		 lwg__psp
# 1814 		 punct 		 rsym
# 1815 		 start2 		 start2
# 1816 		 start1 		 start1
# 1817 		 amod 		 nmod__adj
# 1818 		 dep 		 k1
# 1819 		 root 		 root
# 1820 		 cop 		 lwg_vaux
# 1821 		 punct 		 rsym
# 1822 		 nummod 		 enm
# 1823 		 nmod 		 k7t
# 1824 		 case 		 lwg__psp
# 1825 		 nsubj 		 k1
# 1826 		 nmod 		 lwg__psp
# 1827 		 case 		 r6
# 1828 		 nmod 		 lwg__psp
# 1829 		 case 		 nmod__adj
# 1830 		 case 		 nmod__adj
# 1831 		 cop 		 pof__cn
# 1832 		 cc 		 k1
# 1833 		 obl 		 k7t
# 1834 		 case 		 lwg__psp
# 1835 		 advmod 		 rd
# 1836 		 advcl 		 lwg__psp
# 1837 		 mark 		 lwg__psp
# 1838 		 mark 		 lwg__psp
# 1839 		 det 		 mod_wq
# 1840 		 nsubj 		 k1
# 1841 		 dep 		 lwg__psp
# 1842 		 compound 		 r6
# 1843 		 compound 		 lwg__psp
# 1844 		 nmod 		 nmod__adj
# 1845 		 case 		 nmod__adj
# 1846 		 obl 		 k7t
# 1847 		 case 		 lwg__psp
# 1848 		 advmod 		 rd
# 1849 		 conj 		 ccof
# 1850 		 punct 		 rsym
# 1851 		 start2 		 start2
# 1852 		 start1 		 start1
# 1853 		 obl 		 k7t
# 1854 		 case 		 lwg__psp
# 1855 		 obl 		 k7t
# 1856 		 nsubj 		 k1
# 1857 		 case 		 r6
# 1858 		 obl 		 k7t
# 1859 		 advcl 		 lwg__psp
# 1860 		 iobj 		 k4
# 1861 		 case 		 lwg__psp
# 1862 		 acl:relcl 		 nmod__adj
# 1863 		 punct 		 rsym
# 1864 		 mark 		 lwg__psp
# 1865 		 iobj 		 k4
# 1866 		 nummod 		 enm
# 1867 		 obl 		 k7t
# 1868 		 case 		 lwg__psp
# 1869 		 nummod 		 enm
# 1870 		 nmod 		 k7t
# 1871 		 case 		 lwg__psp
# 1872 		 nsubj 		 k1
# 1873 		 acl:relcl 		 lwg__psp
# 1874 		 aux 		 r6
# 1875 		 aux:pass 		 lwg_vaux
# 1876 		 punct 		 rsym
# 1877 		 obl 		 k7t
# 1878 		 nsubj 		 k1
# 1879 		 root 		 root
# 1880 		 aux 		 lwg_vaux
# 1881 		 start2 		 start2
# 1882 		 start1 		 start1
# 1883 		 obl 		 k7t
# 1884 		 case 		 lwg__psp
# 1885 		 nmod 		 lwg__psp
# 1886 		 nsubj 		 k1
# 1887 		 det 		 mod_wq
# 1888 		 dep 		 k1
# 1889 		 compound 		 lwg__psp
# 1890 		 root 		 root
# 1891 		 aux 		 lwg_vaux
# 1892 		 punct 		 rsym
# 1893 		 start2 		 start2
# 1894 		 start1 		 start1
# 1895 		 nmod 		 nmod__adj
# 1896 		 nummod 		 enm
# 1897 		 nmod 		 k7t
# 1898 		 case 		 lwg__psp
# 1899 		 amod 		 lwg__psp
# 1900 		 root 		 root
# 1901 		 cop 		 lwg_vaux
# 1902 		 punct 		 rsym
# 1903 		 start2 		 start2
# 1904 		 start1 		 start1
# 1905 		 dep 		 nmod__adj
# 1906 		 dep 		 k1
# 1907 		 nsubj 		 k1
# 1908 		 advmod 		 r6
# 1909 		 root 		 root
# 1910 		 start2 		 start2
# 1911 		 start1 		 start1
# 1912 		 nmod 		 nmod__adj
# 1913 		 case 		 k1
# 1914 		 det 		 mod_wq
# 1915 		 det 		 mod_wq
# 1916 		 acl:relcl 		 k1
# 1917 		 cop 		 lwg__psp
# 1918 		 punct 		 rsym
# 1919 		 nsubj 		 k1
# 1920 		 root 		 root
# 1921 		 aux 		 lwg_vaux
# 1922 		 aux:pass 		 lwg_vaux
# 1923 		 punct 		 rsym
# 1924 		 start2 		 start2
# 1925 		 start1 		 start1
# 1926 		 nmod 		 nmod__adj
# 1927 		 case 		 k1
# 1928 		 nsubj 		 k1
# 1929 		 obl 		 k7t
# 1930 		 case 		 lwg__psp
# 1931 		 root 		 root
# 1932 		 aux 		 lwg_vaux
# 1933 		 aux:pass 		 lwg_vaux
# 1934 		 punct 		 rsym
# 1935 		 start2 		 start2
# 1936 		 start1 		 start1
# 1937 		 det 		 mod_wq
# 1938 		 obl 		 k1
# 1939 		 case 		 lwg__psp
# 1940 		 nsubj 		 k1
# 1941 		 advcl 		 lwg__psp
# 1942 		 aux 		 r6
# 1943 		 aux:pass 		 lwg_vaux
# 1944 		 punct 		 rsym
# 1945 		 compound 		 rsym
# 1946 		 root 		 root
# 1947 		 aux 		 lwg_vaux
# 1948 		 aux:pass 		 lwg_vaux
# 1949 		 punct 		 rsym
# 1950 		 start2 		 start2
# 1951 		 start1 		 start1
# 1952 		 nmod 		 nmod__adj
# 1953 		 case 		 k1
# 1954 		 nsubj 		 k1
# 1955 		 obl 		 k7t
# 1956 		 case 		 lwg__psp
# 1957 		 case 		 lwg__psp
# 1958 		 root 		 root
# 1959 		 aux 		 lwg_vaux
# 1960 		 aux:pass 		 lwg_vaux
# 1961 		 punct 		 rsym
# 1962 		 start2 		 start2
# 1963 		 start1 		 start1
# 1964 		 nummod 		 enm
# 1965 		 nmod 		 k7t
# 1966 		 case 		 lwg__psp
# 1967 		 nsubj 		 k1
# 1968 		 advcl 		 lwg__psp
# 1969 		 punct 		 rsym
# 1970 		 mark 		 lwg__psp
# 1971 		 amod 		 lwg__psp
# 1972 		 nmod 		 pof
# 1973 		 case 		 main
# 1974 		 compound 		 lwg__vaux
# 1975 		 root 		 root
# 1976 		 punct 		 rsym
# 1977 		 start2 		 start2
# 1978 		 start1 		 start1
# 1979 		 nsubj 		 k1
# 1980 		 case 		 nmod__adj
# 1981 		 acl 		 k1s
# 1982 		 aux 		 main
# 1983 		 nsubj 		 k1
# 1984 		 case 		 lwg__psp
# 1985 		 obl 		 k7t
# 1986 		 case 		 lwg__psp
# 1987 		 nsubj 		 k1
# 1988 		 obj 		 k2
# 1989 		 root 		 root
# 1990 		 punct 		 rsym
# 1991 		 start2 		 start2
# 1992 		 start1 		 start1
# 1993 		 obl 		 k7t
# 1994 		 case 		 lwg__psp
# 1995 		 root 		 root
# 1996 		 advmod 		 lwg_vaux
# 1997 		 mark 		 lwg__psp
# 1998 		 obl 		 k7t
# 1999 		 case 		 lwg__psp
# 2000 		 case 		 lwg__psp
# 2001 		 compound 		 pof
# 2002 		 nsubj 		 k1
# 2003 		 aux 		 pof
# 2004 		 aux:pass 		 lwg_vaux
# 2005 		 nsubj 		 k7t
# 2006 		 punct 		 rsym
# 2007 		 nsubj 		 k1
# 2008 		 punct 		 rsym
# 2009 		 nummod 		 enm
# 2010 		 nmod 		 k7t
# 2011 		 case 		 lwg__psp
# 2012 		 compound 		 lwg__psp
# 2013 		 advcl 		 rh
# 2014 		 conj 		 ccof
# 2015 		 aux 		 lwg__vaux
# 2016 		 cc 		 k1
# 2017 		 obl 		 k7t
# 2018 		 nummod 		 enm
# 2019 		 obl 		 k7t
# 2020 		 case 		 lwg__psp
# 2021 		 obj 		 k2
# 2022 		 advmod 		 lwg__psp
# 2023 		 conj 		 ccof
# 2024 		 punct 		 rsym
# 2025 		 start2 		 start2
# 2026 		 start1 		 start1
# 2027 		 nsubj 		 k1
# 2028 		 case 		 nmod__adj
# 2029 		 det 		 mod_wq
# 2030 		 nsubj 		 k1
# 2031 		 xcomp 		 k2
# 2032 		 root 		 root
# 2033 		 aux 		 lwg_vaux
# 2034 		 cc 		 k1
# 2035 		 nmod 		 lwg__psp
# 2036 		 compound 		 r6
# 2037 		 conj 		 ccof
# 2038 		 aux 		 lwg__psp
# 2039 		 mark 		 lwg__psp
# 2040 		 nmod 		 pof
# 2041 		 case 		 main
# 2042 		 compound 		 lwg__vaux
# 2043 		 acl 		 start2
# 2044 		 aux 		 start1
# 2045 		 punct 		 rsym
# 2046 		 cc 		 k1
# 2047 		 amod 		 nmod__adj
# 2048 		 nmod 		 k1s
# 2049 		 cc 		 k1
# 2050 		 amod 		 lwg__psp
# 2051 		 conj 		 ccof
# 2052 		 case 		 main
# 2053 		 obj 		 k2
# 2054 		 advcl 		 lwg__psp
# 2055 		 obj 		 k2
# 2056 		 nsubj 		 k1
# 2057 		 mark 		 lwg__psp
# 2058 		 conj 		 ccof
# 2059 		 aux 		 main
# 2060 		 punct 		 rsym
# 2061 		 start2 		 start2
# 2062 		 start1 		 start1
# 2063 		 mark 		 lwg__psp
# 2064 		 punct 		 rsym
# 2065 		 obl 		 k7t
# 2066 		 nsubj 		 k1
# 2067 		 case 		 r6
# 2068 		 obl 		 k7t
# 2069 		 case 		 lwg__psp
# 2070 		 compound 		 lwg__psp
# 2071 		 root 		 root
# 2072 		 cc 		 k1
# 2073 		 nmod 		 lwg__psp
# 2074 		 case 		 r6
# 2075 		 nsubj 		 k1
# 2076 		 conj 		 ccof
# 2077 		 aux 		 main
# 2078 		 punct 		 rsym
# 2079 		 start2 		 start2
# 2080 		 start1 		 start1
# 2081 		 nsubj 		 k1
# 2082 		 case 		 nmod__adj
# 2083 		 compound 		 k1s
# 2084 		 advcl 		 main
# 2085 		 root 		 root
# 2086 		 punct 		 rsym
# 2087 		 nsubj 		 k1
# 2088 		 obj 		 k2
# 2089 		 aux 		 nmod__relc
# 2090 		 mark 		 lwg__psp
# 2091 		 advmod 		 rd
# 2092 		 punct 		 rsym
# 2093 		 nsubj 		 k1
# 2094 		 nmod 		 nmod__adj
# 2095 		 compound 		 k1s
# 2096 		 obj 		 main
# 2097 		 aux 		 start2
# 2098 		 punct 		 rsym
# 2099 		 start2 		 start2
# 2100 		 start1 		 start1
# 2101 		 cc 		 k1
# 2102 		 nsubj 		 k1
# 2103 		 nmod 		 r6
# 2104 		 dep 		 lwg__psp
# 2105 		 compound 		 nmod__adj
# 2106 		 root 		 root
# 2107 		 punct 		 rsym
# 2108 		 cc 		 k1
# 2109 		 nsubj 		 k1
# 2110 		 nsubj 		 k1
# 2111 		 dep 		 r6
# 2112 		 advmod 		 lwg__psp
# 2113 		 conj 		 ccof
# 2114 		 aux 		 main
# 2115 		 punct 		 rsym
# 2116 		 start2 		 start2
# 2117 		 start1 		 start1
# 2118 		 advcl 		 rh
# 2119 		 punct 		 rsym
# 2120 		 obl 		 k7t
# 2121 		 dep 		 pof__cn
# 2122 		 nmod 		 pof__cn
# 2123 		 case 		 pof__cn
# 2124 		 nmod 		 pof__cn
# 2125 		 case 		 pof__cn
# 2126 		 compound 		 pof__cn
# 2127 		 root 		 root
# 2128 		 punct 		 rsym
# 2129 		 nsubj 		 k1
# 2130 		 case 		 nmod__adj
# 2131 		 compound 		 k1s
# 2132 		 advcl 		 main
# 2133 		 aux 		 start2
# 2134 		 conj 		 ccof
# 2135 		 nsubj 		 k1
# 2136 		 nmod 		 r6
# 2137 		 nmod 		 lwg__psp
# 2138 		 case 		 nmod__adj
# 2139 		 conj 		 ccof
# 2140 		 cop 		 k2
# 2141 		 punct 		 rsym
# 2142 		 nmod 		 start2
# 2143 		 case 		 start1
# 2144 		 det 		 mod_wq
# 2145 		 nmod 		 k1
# 2146 		 punct 		 rsym
# 2147 		 start2 		 start2
# 2148 		 start1 		 start1
# 2149 		 cc 		 k1
# 2150 		 obl 		 k7t
# 2151 		 case 		 lwg__psp
# 2152 		 advcl 		 rh
# 2153 		 obj 		 k2
# 2154 		 root 		 root
# 2155 		 punct 		 rsym
# 2156 		 obl 		 k7t
# 2157 		 case 		 pof__cn
# 2158 		 case 		 pof__cn
# 2159 		 nmod 		 pof__cn
# 2160 		 obl 		 k7t
# 2161 		 case 		 lwg__psp
# 2162 		 nsubj 		 k1
# 2163 		 compound 		 lwg__psp
# 2164 		 acl 		 r6
# 2165 		 aux 		 lwg__psp
# 2166 		 aux:pass 		 lwg_vaux
# 2167 		 punct 		 rsym
