# %%
file = open('../assgn4/UD/hi_hdtb-ud-train.conllu.txt', 'r').read()
sentences = file.split('\n\n')
for sentence in sentences:
    words = sentence.split('\n')
    if len(words)<=10:
        print(words[0])        
        print(words[1])
# Out:
# # sent_id = train-s2
# # text = इसे नवाब शाहजेहन ने बनवाया था ।
# # sent_id = train-s3
# # text = इसका प्रवेश द्वार दो मंजिला है ।
# # sent_id = train-s5
# # text = पूरी इमारत बेहद खूबसूरत है ।
# # sent_id = train-s9
# # text = यह भारत की अनूठी राष्ट्रीय संस्था है ।
# # sent_id = train-s11
# # text = इसे चार्ल्स कोरिया ने डिजाइन किया है ।
# # sent_id = train-s21
# # text = संग्रहालय सोमवार को बंद रहता है ।
# # sent_id = train-s22
# # text = यह अरेरा हिल्स पर स्थित है ।
# # sent_id = train-s26
# # text = यह 445 हैक्टेयर में फैला है ।
# # sent_id = train-s38
# # text = कैसे पहुँचे?
# # sent_id = train-s44
# # text = कब जाएँ?
# # sent_id = train-s67
# # text = यह अफगानी कला का बेजोड़ उदाहरण है.
# # sent_id = train-s84
# # text = कैसे जाएँ
# # sent_id = train-s88
# # text = कब जाएँ,
# # sent_id = train-s115
# # text = यहाँ आम पर्यटक को प्रवेश नहीं मिलता ।
# # sent_id = train-s135
# # text = बिना चूके उसका टिकट ले लीजिए ।
# # sent_id = train-s147
# ...
