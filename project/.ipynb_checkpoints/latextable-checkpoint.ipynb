# %%
file = open('markers-tags-wx.txt', 'r').read()

# %%
markers = file.split("\n\n")

# %%
for marker in markers:
    mark = marker.split("\n")[0].split(', ')[0]
    tags = marker.split("\n")
    if len(tags) == 1 and int(tags[0].split(', ')[2])>3:
        print('\hline')
        print(mark, '&', tags[0].split(', ')[1], '&', tags[0].split(', ')[2], '\\\\')
    else:
        print('\hline')
        print('\multirow{', len(tags), '}{*}{',mark,'}', '&', tags[0].split(', ')[1] ,'&', tags[0].split(', ')[2],'\\\\')
        for i in range(len(tags)-1):
            tokens = tags[i+1].split(', ')
            if int(tokens[2])>3:
                print('&', tokens[1] ,'&', tokens[2],'\\\\')
# Out:
# \hline
# \multirow{ 3 }{*}{ alAvA } & k7a & 2 \\
# & sent-adv & 7 \\
# \hline
# \multirow{ 3 }{*}{ alAvA } & k7a & 2 \\
# & vmod & 112 \\
# \hline
# OYna & pof\_\_cn & 7 \\
# \hline
# OYPa & pof\_\_cn & 5 \\
# \hline
# \multirow{ 23 }{*}{ kA } & ccof & 141 \\
# & k1 & 300 \\
# \hline
# \multirow{ 23 }{*}{ kA } & ccof & 141 \\
# & k2 & 4 \\
# \hline
# \multirow{ 23 }{*}{ kA } & ccof & 141 \\
# & lwg\_\_psp & 7 \\
# \hline
# \multirow{ 23 }{*}{ kA } & ccof & 141 \\
# & lwg\_\_vaux & 29 \\
# \hline
# \multirow{ 23 }{*}{ kA } & ccof & 141 \\
# & nmod & 11 \\
# \hline
# \multirow{ 23 }{*}{ kA } & ccof & 141 \\
# & r6 & 2007 \\
# \hline
# \multirow{ 23 }{*}{ kA } & ccof & 141 \\
# & r6-k1 & 177 \\
# \hline
# \multirow{ 23 }{*}{ kA } & ccof & 141 \\
# & r6-k2 & 1044 \\
# \hline
# \multirow{ 23 }{*}{ kA } & ccof & 141 \\
# & r6v & 7 \\
# \hline
# \multirow{ 23 }{*}{ kA } & ccof & 141 \\
# & ras-k2 & 4 \\
# \hline
# \multirow{ 23 }{*}{ kA } & ccof & 141 \\
# & rsym & 37 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & ccof & 312 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & jjmod & 21 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & k1 & 11 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & k1u & 23 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & k2 & 7 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & k2u & 12 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & k5 & 5 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & k7 & 21 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & k7t & 4 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & lwg\_\_psp & 10 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & lwg\_\_rp & 10 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & lwg\_\_vaux & 106 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & nmod & 39 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & pof\_\_cn & 11 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & pof\_\_redup & 4 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & r6 & 4784 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & r6-k1 & 188 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & r6-k2 & 915 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & r6v & 6 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & ras-k2 & 5 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & rd & 182 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & rh & 53 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & rsym & 70 \\
# \hline
# \multirow{ 38 }{*}{ kI } & adv & 3 \\
# & rt & 4 \\
# \hline
# \multirow{ 6 }{*}{ kI waraha } & adv & 3 \\
# & k1u & 5 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & ccof & 531 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & jjmod & 31 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & k1 & 160 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & k1u & 14 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & k2 & 24 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & k2p & 5 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & k3 & 11 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & k4 & 4 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & k5 & 15 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & k7 & 557 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & k7a & 39 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & k7p & 182 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & k7t & 986 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & lwg\_\_psp & 11 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & lwg\_\_rp & 19 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & lwg\_\_vaux & 81 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & lwg\_\_vaux\_cont & 5 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & nmod & 55 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & pof\_\_cn & 20 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & r6 & 6312 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & r6-k1 & 41 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & r6-k2 & 88 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & r6v & 8 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & ras-k1 & 320 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & ras-k2 & 80 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & ras-k7 & 6 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & ras-neg & 29 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & rh & 190 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & rs & 4 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & rsym & 124 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & rt & 6 \\
# \hline
# \multirow{ 51 }{*}{ ke } & adv & 11 \\
# & vmod & 178 \\
# \hline
# ke aMwargawa & k7a & 7 \\
# \hline
# ke anusAra & k7a & 126 \\
# \hline
# \multirow{ 3 }{*}{ ke alAvA } & ccof & 19 \\
# & vmod & 68 \\
# \hline
# \multirow{ 3 }{*}{ ke kAraNa } & ccof & 2 \\
# & rh & 10 \\
# \hline
# \multirow{ 4 }{*}{ ke KilAPa } & ccof & 6 \\
# & vmod & 89 \\
# \hline
# \multirow{ 2 }{*}{ ke KilAPZ } & k2 & 1 \\
# & vmod & 8 \\
# \hline
# \multirow{ 3 }{*}{ ke calawe } & ccof & 2 \\
# & rh & 37 \\
# \hline
# \multirow{ 5 }{*}{ ke jarie } & ccof & 6 \\
# & k3 & 78 \\
# \hline
# \multirow{ 3 }{*}{ ke jariye } & ccof & 1 \\
# & k3 & 18 \\
# \hline
# \multirow{ 3 }{*}{ ke wahawa } & ccof & 6 \\
# & k7a & 125 \\
# \hline
# \multirow{ 3 }{*}{ ke wahawa } & ccof & 6 \\
# & rsym & 6 \\
# \hline
# \multirow{ 3 }{*}{ ke xvArA } & ccof & 2 \\
# & k1 & 5 \\
# \hline
# \multirow{ 5 }{*}{ ke prawi } & ccof & 4 \\
# & rd & 45 \\
# \hline
# \multirow{ 3 }{*}{ ke bajAe } & k7 & 1 \\
# & ras-neg & 4 \\
# \hline
# \multirow{ 3 }{*}{ ke bajAya } & ccof & 1 \\
# & ras-neg & 8 \\
# \hline
# \multirow{ 3 }{*}{ ke bajAya } & ccof & 1 \\
# & vmod & 10 \\
# \hline
# \multirow{ 8 }{*}{ ke bAre meM } & ccof & 21 \\
# & k7 & 192 \\
# \hline
# \multirow{ 8 }{*}{ ke bAre meM } & ccof & 21 \\
# & lwg\_\_vaux & 5 \\
# \hline
# \multirow{ 3 }{*}{ ke bAvajUxa } & k7a & 3 \\
# & lwg\_\_vaux & 5 \\
# \hline
# \multirow{ 3 }{*}{ ke bAvajUxa } & k7a & 3 \\
# & vmod & 62 \\
# \hline
# \multirow{ 6 }{*}{ ke maxxenajara } & ccof & 1 \\
# & k7a & 25 \\
# \hline
# \multirow{ 6 }{*}{ ke maxxenajara } & ccof & 1 \\
# & vmod & 4 \\
# \hline
# \multirow{ 3 }{*}{ ke maxxenajZra } & ccof & 1 \\
# & k7a & 5 \\
# \hline
# \multirow{ 3 }{*}{ ke muwAbika } & ccof & 1 \\
# & k7a & 266 \\
# \hline
# \multirow{ 2 }{*}{ ke muwAbikZ } & k7 & 1 \\
# & k7a & 10 \\
# \hline
# \multirow{ 15 }{*}{ ke lie } & ccof & 75 \\
# & jjmod & 12 \\
# \hline
# \multirow{ 15 }{*}{ ke lie } & ccof & 75 \\
# & k2 & 4 \\
# \hline
# \multirow{ 15 }{*}{ ke lie } & ccof & 75 \\
# & k7t & 5 \\
# \hline
# \multirow{ 15 }{*}{ ke lie } & ccof & 75 \\
# & lwg\_\_vaux & 13 \\
# \hline
# \multirow{ 15 }{*}{ ke lie } & ccof & 75 \\
# & nmod & 13 \\
# \hline
# \multirow{ 15 }{*}{ ke lie } & ccof & 75 \\
# & r6 & 9 \\
# \hline
# \multirow{ 15 }{*}{ ke lie } & ccof & 75 \\
# & rh & 10 \\
# \hline
# \multirow{ 15 }{*}{ ke lie } & ccof & 75 \\
# & rsym & 8 \\
# \hline
# \multirow{ 15 }{*}{ ke lie } & ccof & 75 \\
# & rt & 1565 \\
# \hline
# ke viruxXa & vmod & 4 \\
# \hline
# ke saMbaMXa meM & k7 & 5 \\
# \hline
# \multirow{ 5 }{*}{ ke samAna } & k1s & 1 \\
# & k1u & 5 \\
# \hline
# ke jZrie & k3 & 6 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & jjmod & 15 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & jk1 & 4 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & k1 & 367 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & k2 & 2769 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & k2g & 4 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & k4 & 1439 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & k4a & 243 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & k7p & 12 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & k7t & 1009 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & lwg\_\_rp & 4 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & lwg\_\_vaux & 11 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & nmod & 13 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & rsym & 42 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & rt & 93 \\
# \hline
# \multirow{ 28 }{*}{ ko } & ccof & 288 \\
# & vmod & 5 \\
# \hline
# \multirow{ 3 }{*}{ KilAPa } & jjmod & 1 \\
# & vmod & 15 \\
# \hline
# \multirow{ 2 }{*}{ calawe } & rh & 12 \\
# & vmod & 6 \\
# \hline
# \multirow{ 5 }{*}{ jEsA } & adv & 1 \\
# & nmod & 6 \\
# \hline
# \multirow{ 7 }{*}{ jEsI } & ccof & 13 \\
# & k1u & 5 \\
# \hline
# \multirow{ 7 }{*}{ jEsI } & ccof & 13 \\
# & k2u & 4 \\
# \hline
# \multirow{ 7 }{*}{ jEsI } & ccof & 13 \\
# & nmod & 9 \\
# \hline
# \multirow{ 9 }{*}{ jEse } & ccof & 44 \\
# & k1u & 7 \\
# \hline
# \multirow{ 9 }{*}{ jEse } & ccof & 44 \\
# & k2u & 4 \\
# \hline
# \multirow{ 9 }{*}{ jEse } & ccof & 44 \\
# & nmod & 23 \\
# \hline
# \multirow{ 9 }{*}{ jEse } & ccof & 44 \\
# & rsym & 5 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & ccof & 11 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & k1 & 5 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & k1s & 8 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & k2 & 6 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & k2p & 20 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & k7 & 79 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & k7p & 33 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & k7t & 440 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & lwg\_\_psp & 14 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & nmod & 6 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & sent-adv & 17 \\
# \hline
# \multirow{ 22 }{*}{ waka } & adv & 2 \\
# & vmod & 9 \\
# \hline
# \multirow{ 4 }{*}{ waka kI } & r6 & 7 \\
# & r6-k2 & 4 \\
# \hline
# \multirow{ 2 }{*}{ waka ke } & k7t & 1 \\
# & r6 & 6 \\
# \hline
# \multirow{ 2 }{*}{ waka ke lie } & k7t & 5 \\
# & rt & 8 \\
# \hline
# \multirow{ 3 }{*}{ wahawa } & k7 & 2 \\
# & k7a & 31 \\
# \hline
# \multirow{ 11 }{*}{ xvArA } & ccof & 19 \\
# & jjmod & 40 \\
# \hline
# \multirow{ 11 }{*}{ xvArA } & ccof & 19 \\
# & k1 & 294 \\
# \hline
# \multirow{ 11 }{*}{ xvArA } & ccof & 19 \\
# & k3 & 29 \\
# \hline
# \multirow{ 11 }{*}{ xvArA } & ccof & 19 \\
# & nmod & 11 \\
# \hline
# \multirow{ 11 }{*}{ xvArA } & ccof & 19 \\
# & rsym & 8 \\
# \hline
# \multirow{ 8 }{*}{ ne } & ccof & 144 \\
# & k1 & 4916 \\
# \hline
# \multirow{ 8 }{*}{ ne } & ccof & 144 \\
# & lwg\_\_rp & 4 \\
# \hline
# \multirow{ 8 }{*}{ ne } & ccof & 144 \\
# & rsym & 48 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & ccof & 102 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & jjmod & 54 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & k2 & 26 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & k2p & 11 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & k7 & 2364 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & k7p & 615 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & k7t & 54 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & lwg\_\_psp & 32 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & lwg\_\_vaux & 63 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & nmod & 33 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & pof\_\_redup & 7 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & rh & 6 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & rsym & 14 \\
# \hline
# \multirow{ 21 }{*}{ para } & adv & 16 \\
# & vmod & 15 \\
# \hline
# bakOla & </s> & 10 \\
# \hline
# \multirow{ 3 }{*}{ bAbawa } & k2 & 1 \\
# & k7 & 5 \\
# \hline
# bAre meM & k7 & 105 \\
# \hline
# \multirow{ 2 }{*}{ bAvajUxa } & k7a & 4 \\
# & vmod & 10 \\
# \hline
# \multirow{ 2 }{*}{ maxxenajara } & jjmod & 1 \\
# & k7a & 4 \\
# \hline
# \multirow{ 2 }{*}{ muwAbika } & k7 & 1 \\
# & k7a & 13 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & ccof & 263 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & jjmod & 137 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & k1 & 7 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & k2 & 14 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & k2p & 18 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & k7 & 4180 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & k7p & 2827 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & k7t & 670 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & lwg\_\_psp & 182 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & lwg\_\_rp & 70 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & lwg\_\_vaux & 8 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & nmod & 131 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & pof & 7 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & rd & 4 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & rsym & 42 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & rt & 4 \\
# \hline
# \multirow{ 28 }{*}{ meM } & adv & 22 \\
# & sent-adv & 5 \\
# \hline
# \multirow{ 5 }{*}{ meM se } & ccof & 3 \\
# & k5 & 37 \\
# \hline
# \multirow{ 5 }{*}{ meM se } & ccof & 3 \\
# & k7 & 14 \\
# \hline
# \multirow{ 5 }{*}{ meM se } & ccof & 3 \\
# & nmod & 4 \\
# \hline
# \multirow{ 4 }{*}{ lie } & k4a & 1 \\
# & rt & 141 \\
# \hline
# \multirow{ 8 }{*}{ vAlA } & ccof & 4 \\
# & k1s & 7 \\
# \hline
# \multirow{ 8 }{*}{ vAlA } & ccof & 4 \\
# & nmod & 36 \\
# \hline
# \multirow{ 7 }{*}{ vAlI } & ccof & 11 \\
# & lwg\_\_vaux & 16 \\
# \hline
# \multirow{ 7 }{*}{ vAlI } & ccof & 11 \\
# & nmod & 204 \\
# \hline
# \multirow{ 7 }{*}{ vAlI } & ccof & 11 \\
# & nmod\_\_k1inv & 12 \\
# \hline
# \multirow{ 14 }{*}{ vAle } & ccof & 10 \\
# & k1 & 12 \\
# \hline
# \multirow{ 14 }{*}{ vAle } & ccof & 10 \\
# & lwg\_\_vaux & 35 \\
# \hline
# \multirow{ 14 }{*}{ vAle } & ccof & 10 \\
# & nmod & 352 \\
# \hline
# \multirow{ 14 }{*}{ vAle } & ccof & 10 \\
# & nmod\_\_k1inv & 15 \\
# \hline
# \multirow{ 3 }{*}{ vAloM kI } & ccof & 1 \\
# & r6 & 5 \\
# \hline
# vAloM ke lie & rt & 4 \\
# \hline
# \multirow{ 4 }{*}{ vAloM ko } & ccof & 2 \\
# & k4 & 8 \\
# \hline
# vAloM meM & k7 & 8 \\
# \hline
# \multirow{ 9 }{*}{ samewa } & ccof & 43 \\
# & ras-k1 & 14 \\
# \hline
# \multirow{ 9 }{*}{ samewa } & ccof & 43 \\
# & ras-k2 & 5 \\
# \hline
# \multirow{ 9 }{*}{ samewa } & ccof & 43 \\
# & vmod & 50 \\
# \hline
# \multirow{ 9 }{*}{ sahiwa } & adv & 1 \\
# & ccof & 26 \\
# \hline
# \multirow{ 9 }{*}{ sahiwa } & adv & 1 \\
# & ras-k1 & 9 \\
# \hline
# \multirow{ 9 }{*}{ sahiwa } & adv & 1 \\
# & ras-k2 & 7 \\
# \hline
# \multirow{ 9 }{*}{ sahiwa } & adv & 1 \\
# & vmod & 14 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & ccof & 166 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & jjmod & 228 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k1 & 11 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k1s & 7 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k1u & 10 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k2 & 443 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k2g & 5 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k2p & 7 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k2s & 6 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k2u & 4 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k3 & 297 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k4 & 275 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k5 & 1037 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k7 & 62 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k7p & 79 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & k7t & 298 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & lwg\_\_psp & 303 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & lwg\_\_rp & 4 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & lwg\_\_vaux & 30 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & nmod & 164 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & pof\_\_redup & 4 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & r6 & 5 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & ras-k1 & 235 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & ras-k2 & 41 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & rd & 7 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & rh & 401 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & rsp & 120 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & rsym & 28 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & rt & 46 \\
# \hline
# \multirow{ 42 }{*}{ se } & adv & 445 \\
# & vmod & 61 \\
# \hline
# \multirow{ 4 }{*}{ se lekara } & ccof & 2 \\
# & nmod & 4 \\
# \hline
# \multirow{ 4 }{*}{ se lekara } & ccof & 2 \\
# & rsp & 16 \\
